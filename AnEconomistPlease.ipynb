# %% [markdown]
# <a href="https://colab.research.google.com/github/eniktab/MoE_nlp/blob/master/AnEconomistPlease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.

# %%
import tensorflow as tf
import numpy as np
import os
import time
import random


trained_model_path = ["https://storage.googleapis.com/bucket-1-free/%20philip/ArthurGrimes.txt", 
                    "https://storage.googleapis.com/bucket-1-free/%20philip/ShamubeelEaqubs.txt"]
# !rm -r /content/training_checkpoints
for i in trained_model_path:
        tf.keras.utils.get_file(
            i.split("/")[-1], i, cache_subdir=os.path.abspath("/content"))

ecolist = ['/content/ArthurGrimes.txt', '/content/ShamubeelEaqubs.txt']
temtxt= random.choice(ecolist)     
# Read, then decode for py2 compat.
text = open(temtxt, 'rb').read().decode(encoding='utf-8')
print('Length of text: {} characters'.format(len(text)))
# The unique characters in the file
vocab = sorted(set(text))
char2idx = {u:i for i, u in enumerate(vocab)}
idx2char = np.array(vocab)
text_as_int = np.array([char2idx[c] for c in text])
# The maximum length sentence you want for a single input in characters
seq_length = 100
examples_per_epoch = len(text)//(seq_length+1)
# Create training examples / targets
char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)
sequences = char_dataset.batch(seq_length+1, drop_remainder=True)
def split_input_target(chunk):
    input_text = chunk[:-1]
    target_text = chunk[1:]
    return input_text, target_text
dataset = sequences.map(split_input_target)
# Batch size
BATCH_SIZE = 64
BUFFER_SIZE = 10000
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
vocab_size = len(vocab)
embedding_dim = 256
rnn_units = 1024
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim,
                                  batch_input_shape=[batch_size, None]),
        tf.keras.layers.GRU(rnn_units,
                            return_sequences=True,
                            stateful=True,
                            recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size)
    ])
    return model
model = build_model(
    vocab_size=len(vocab),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
    batch_size=BATCH_SIZE)
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
model.compile(optimizer='adam', loss=loss)
# Directory where the checkpoints will be saved
checkpoint_dir = './training_checkpoints/ArthurGrimes'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True
    )

model = build_model(
    vocab_size=len(vocab),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
    batch_size=BATCH_SIZE)

optimizer = tf.keras.optimizers.Adam()

@tf.function
def train_step(inp, target):
    with tf.GradientTape() as tape:
        predictions = model(inp)
        loss = tf.reduce_mean(
            tf.keras.losses.sparse_categorical_crossentropy(
                target, predictions, from_logits=True))
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

    return loss

def generate_text(model, start_string):
    # Evaluation step (generating text using the learned model)

    # Number of characters to generate
    num_generate = 1000

    # Converting our start string to numbers (vectorizing)
    input_eval = [char2idx[s] for s in start_string]
    input_eval = tf.expand_dims(input_eval, 0)

    # Empty string to store our results
    text_generated = []

    # Low temperature results in more predictable text.
    # Higher temperature results in more surprising text.
    # Experiment to find the best setting.
    temperature = 0.5

    model.reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)
        # remove the batch dimension
        predictions = tf.squeeze(predictions, 0)

        # using a categorical distribution to predict the character returned by the model
        predictions = predictions / temperature
        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

        # Pass the predicted character as the next input to the model
        # along with the previous hidden state
        input_eval = tf.expand_dims([predicted_id], 0)

        text_generated.append(idx2char[predicted_id])

    return (start_string + ''.join(text_generated))
  
tf.train.latest_checkpoint(checkpoint_dir)
# Training step
EPOCHS = 1500

for epoch in range(EPOCHS):
    start = time.time()

    # resetting the hidden state at the start of every epoch
    model.reset_states()

    for (batch_n, (inp, target)) in enumerate(dataset):
        loss = train_step(inp, target)

        if batch_n % 100 == 0:
            template = 'Epoch {} Batch {} Loss {}'
            print(template.format(epoch + 1, batch_n, loss))

    # saving (checkpoint) the model every 5 epochs
    if (epoch + 1) % 5 == 0:
        model.save_weights(checkpoint_prefix.format(epoch=epoch))

    print('Epoch {} Loss {:}'.format(epoch + 1, loss))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

model.save_weights(checkpoint_prefix.format(epoch=epoch))

tf.train.latest_checkpoint(checkpoint_dir)
model = build_model(vocab_size, embedding_dim, rnn_units, batch_size=1)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, None]))
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 251 Batch 0 Loss 0.04342662915587425
# Epoch 251 Loss 0.0911531075835228
# Time taken for 1 epoch 0.13294124603271484 sec
#
# Epoch 252 Batch 0 Loss 0.042454976588487625
# Epoch 252 Loss 0.08568805456161499
# Time taken for 1 epoch 0.1099553108215332 sec
#
# Epoch 253 Batch 0 Loss 0.043992504477500916
# Epoch 253 Loss 0.09024076163768768
# Time taken for 1 epoch 0.11803007125854492 sec
#
# Epoch 254 Batch 0 Loss 0.04118701443076134
# Epoch 254 Loss 0.09083137661218643
# Time taken for 1 epoch 0.11141562461853027 sec
#
# Epoch 255 Batch 0 Loss 0.04077591374516487
# Epoch 255 Loss 0.09088481962680817
# Time taken for 1 epoch 0.13321232795715332 sec
#
# Epoch 256 Batch 0 Loss 0.042754337191581726
# Epoch 256 Loss 0.08252063393592834
# Time taken for 1 epoch 0.11565089225769043 sec
#
# Epoch 257 Batch 0 Loss 0.03834758326411247
# Epoch 257 Loss 0.08907270431518555
# Time taken for 1 epoch 0.12285661697387695 sec
#
# Epoch 258 Batch 0 Loss 0.039091020822525024
# Epoch 258 Loss 0.08821115642786026
# Time taken for 1 epoch 0.10999822616577148 sec
#
# Epoch 259 Batch 0 Loss 0.03971027210354805
# Epoch 259 Loss 0.08710261434316635
# Time taken for 1 epoch 0.11432695388793945 sec
#
# Epoch 260 Batch 0 Loss 0.0392373688519001
# Epoch 260 Loss 0.09282395988702774
# Time taken for 1 epoch 0.14571118354797363 sec
#
# Epoch 261 Batch 0 Loss 0.040609244257211685
# Epoch 261 Loss 0.08269762247800827
# Time taken for 1 epoch 0.12126708030700684 sec
#
# Epoch 262 Batch 0 Loss 0.04253149405121803
# Epoch 262 Loss 0.0856316089630127
# Time taken for 1 epoch 0.10788679122924805 sec
#
# Epoch 263 Batch 0 Loss 0.04168710857629776
# Epoch 263 Loss 0.07670784741640091
# Time taken for 1 epoch 0.10430335998535156 sec
#
# Epoch 264 Batch 0 Loss 0.04002612084150314
# Epoch 264 Loss 0.08852919936180115
# Time taken for 1 epoch 0.10392022132873535 sec
#
# Epoch 265 Batch 0 Loss 0.04043160751461983
# Epoch 265 Loss 0.0845247209072113
# Time taken for 1 epoch 0.13305306434631348 sec
#
# Epoch 266 Batch 0 Loss 0.03832600265741348
# Epoch 266 Loss 0.08801266551017761
# Time taken for 1 epoch 0.12125349044799805 sec
#
# Epoch 267 Batch 0 Loss 0.03852834552526474
# Epoch 267 Loss 0.09042537957429886
# Time taken for 1 epoch 0.11222290992736816 sec
#
# Epoch 268 Batch 0 Loss 0.04117227718234062
# Epoch 268 Loss 0.08862978219985962
# Time taken for 1 epoch 0.10165762901306152 sec
#
# Epoch 269 Batch 0 Loss 0.04188040643930435
# Epoch 269 Loss 0.08510347455739975
# Time taken for 1 epoch 0.11450815200805664 sec
#
# Epoch 270 Batch 0 Loss 0.039301566779613495
# Epoch 270 Loss 0.0889265313744545
# Time taken for 1 epoch 0.14664578437805176 sec
#
# Epoch 271 Batch 0 Loss 0.04035542160272598
# Epoch 271 Loss 0.08124509453773499
# Time taken for 1 epoch 0.12267422676086426 sec
#
# Epoch 272 Batch 0 Loss 0.040297698229551315
# Epoch 272 Loss 0.08515650033950806
# Time taken for 1 epoch 0.10843420028686523 sec
#
# Epoch 273 Batch 0 Loss 0.04078839719295502
# Epoch 273 Loss 0.08175677061080933
# Time taken for 1 epoch 0.10026860237121582 sec
#
# Epoch 274 Batch 0 Loss 0.03851636126637459
# Epoch 274 Loss 0.08671456575393677
# Time taken for 1 epoch 0.12253999710083008 sec
#
# Epoch 275 Batch 0 Loss 0.038700591772794724
# Epoch 275 Loss 0.08047199249267578
# Time taken for 1 epoch 0.14922857284545898 sec
#
# Epoch 276 Batch 0 Loss 0.03843718394637108
# Epoch 276 Loss 0.08489979803562164
# Time taken for 1 epoch 0.11820697784423828 sec
#
# Epoch 277 Batch 0 Loss 0.03977702558040619
# Epoch 277 Loss 0.08790161460638046
# Time taken for 1 epoch 0.1183781623840332 sec
#
# Epoch 278 Batch 0 Loss 0.039408888667821884
# Epoch 278 Loss 0.08644372969865799
# Time taken for 1 epoch 0.11752080917358398 sec
#
# Epoch 279 Batch 0 Loss 0.039609309285879135
# Epoch 279 Loss 0.08209256827831268
# Time taken for 1 epoch 0.10391688346862793 sec
#
# Epoch 280 Batch 0 Loss 0.03802584484219551
# Epoch 280 Loss 0.08381056785583496
# Time taken for 1 epoch 0.15918469429016113 sec
#
# Epoch 281 Batch 0 Loss 0.035139571875333786
# Epoch 281 Loss 0.09174230694770813
# Time taken for 1 epoch 0.1547532081604004 sec
#
# Epoch 282 Batch 0 Loss 0.0374247170984745
# Epoch 282 Loss 0.08778490126132965
# Time taken for 1 epoch 0.12791657447814941 sec
#
# Epoch 283 Batch 0 Loss 0.03770950809121132
# Epoch 283 Loss 0.08550446480512619
# Time taken for 1 epoch 0.1191565990447998 sec
#
# Epoch 284 Batch 0 Loss 0.03917279094457626
# Epoch 284 Loss 0.0704975500702858
# Time taken for 1 epoch 0.11049938201904297 sec
#
# Epoch 285 Batch 0 Loss 0.03686169534921646
# Epoch 285 Loss 0.08393515646457672
# Time taken for 1 epoch 0.15083050727844238 sec
#
# Epoch 286 Batch 0 Loss 0.036128900945186615
# Epoch 286 Loss 0.08112672716379166
# Time taken for 1 epoch 0.12687969207763672 sec
#
# Epoch 287 Batch 0 Loss 0.03927905857563019
# Epoch 287 Loss 0.07306476682424545
# Time taken for 1 epoch 0.10678243637084961 sec
#
# Epoch 288 Batch 0 Loss 0.03880145400762558
# Epoch 288 Loss 0.0789588913321495
# Time taken for 1 epoch 0.11051654815673828 sec
#
# Epoch 289 Batch 0 Loss 0.03757435828447342
# Epoch 289 Loss 0.08098293095827103
# Time taken for 1 epoch 0.12858366966247559 sec
#
# Epoch 290 Batch 0 Loss 0.03823614493012428
# Epoch 290 Loss 0.0792766585946083
# Time taken for 1 epoch 0.15272212028503418 sec
#
# Epoch 291 Batch 0 Loss 0.036583367735147476
# Epoch 291 Loss 0.07693028450012207
# Time taken for 1 epoch 0.11937522888183594 sec
#
# Epoch 292 Batch 0 Loss 0.03506265953183174
# Epoch 292 Loss 0.0800771713256836
# Time taken for 1 epoch 0.11497187614440918 sec
#
# Epoch 293 Batch 0 Loss 0.03792426735162735
# Epoch 293 Loss 0.07290703803300858
# Time taken for 1 epoch 0.11099648475646973 sec
#
# Epoch 294 Batch 0 Loss 0.036010101437568665
# Epoch 294 Loss 0.08142106235027313
# Time taken for 1 epoch 0.11385655403137207 sec
#
# Epoch 295 Batch 0 Loss 0.036789875477552414
# Epoch 295 Loss 0.07379351556301117
# Time taken for 1 epoch 0.14462995529174805 sec
#
# Epoch 296 Batch 0 Loss 0.03684418275952339
# Epoch 296 Loss 0.07533086091279984
# Time taken for 1 epoch 0.11026144027709961 sec
#
# Epoch 297 Batch 0 Loss 0.03974457085132599
# Epoch 297 Loss 0.07107584923505783
# Time taken for 1 epoch 0.10913467407226562 sec
#
# Epoch 298 Batch 0 Loss 0.03632928058505058
# Epoch 298 Loss 0.08120382577180862
# Time taken for 1 epoch 0.1013638973236084 sec
#
# Epoch 299 Batch 0 Loss 0.03937802463769913
# Epoch 299 Loss 0.07816104590892792
# Time taken for 1 epoch 0.1082923412322998 sec
#
# Epoch 300 Batch 0 Loss 0.03829891234636307
# Epoch 300 Loss 0.07574814558029175
# Time taken for 1 epoch 0.1309490203857422 sec
#
# Epoch 301 Batch 0 Loss 0.03757770359516144
# Epoch 301 Loss 0.07427747547626495
# Time taken for 1 epoch 0.10599422454833984 sec
#
# Epoch 302 Batch 0 Loss 0.0357699953019619
# Epoch 302 Loss 0.07504818588495255
# Time taken for 1 epoch 0.10862064361572266 sec
#
# Epoch 303 Batch 0 Loss 0.03506917133927345
# Epoch 303 Loss 0.07238663733005524
# Time taken for 1 epoch 0.10318422317504883 sec
#
# Epoch 304 Batch 0 Loss 0.03690902143716812
# Epoch 304 Loss 0.0743451714515686
# Time taken for 1 epoch 0.10296130180358887 sec
#
# Epoch 305 Batch 0 Loss 0.03615077584981918
# Epoch 305 Loss 0.07647455483675003
# Time taken for 1 epoch 0.1363506317138672 sec
#
# Epoch 306 Batch 0 Loss 0.03937136009335518
# Epoch 306 Loss 0.0724041759967804
# Time taken for 1 epoch 0.10764169692993164 sec
#
# Epoch 307 Batch 0 Loss 0.03616476431488991
# Epoch 307 Loss 0.07383055984973907
# Time taken for 1 epoch 0.10505294799804688 sec
#
# Epoch 308 Batch 0 Loss 0.03571660816669464
# Epoch 308 Loss 0.08000639081001282
# Time taken for 1 epoch 0.10920357704162598 sec
#
# Epoch 309 Batch 0 Loss 0.03728416562080383
# Epoch 309 Loss 0.07277259975671768
# Time taken for 1 epoch 0.10965824127197266 sec
#
# Epoch 310 Batch 0 Loss 0.03604114428162575
# Epoch 310 Loss 0.0714075118303299
# Time taken for 1 epoch 0.13509440422058105 sec
#
# Epoch 311 Batch 0 Loss 0.03629833087325096
# Epoch 311 Loss 0.07079673558473587
# Time taken for 1 epoch 0.1040196418762207 sec
#
# Epoch 312 Batch 0 Loss 0.03638947382569313
# Epoch 312 Loss 0.06710362434387207
# Time taken for 1 epoch 0.11359906196594238 sec
#
# Epoch 313 Batch 0 Loss 0.03615393489599228
# Epoch 313 Loss 0.07307567447423935
# Time taken for 1 epoch 0.11278200149536133 sec
#
# Epoch 314 Batch 0 Loss 0.03633160516619682
# Epoch 314 Loss 0.07872233539819717
# Time taken for 1 epoch 0.11839842796325684 sec
#
# Epoch 315 Batch 0 Loss 0.03754883632063866
# Epoch 315 Loss 0.0686638355255127
# Time taken for 1 epoch 0.17507100105285645 sec
#
# Epoch 316 Batch 0 Loss 0.03648115694522858
# Epoch 316 Loss 0.06823596358299255
# Time taken for 1 epoch 0.1651167869567871 sec
#
# Epoch 317 Batch 0 Loss 0.037190210074186325
# Epoch 317 Loss 0.07016225904226303
# Time taken for 1 epoch 0.11391973495483398 sec
#
# Epoch 318 Batch 0 Loss 0.03483748063445091
# Epoch 318 Loss 0.06990265101194382
# Time taken for 1 epoch 0.12366199493408203 sec
#
# Epoch 319 Batch 0 Loss 0.036786094307899475
# Epoch 319 Loss 0.07430630177259445
# Time taken for 1 epoch 0.12588930130004883 sec
#
# Epoch 320 Batch 0 Loss 0.03589308634400368
# Epoch 320 Loss 0.07268041372299194
# Time taken for 1 epoch 0.14715003967285156 sec
#
# Epoch 321 Batch 0 Loss 0.03393309935927391
# Epoch 321 Loss 0.0692145898938179
# Time taken for 1 epoch 0.11118531227111816 sec
#
# Epoch 322 Batch 0 Loss 0.035655342042446136
# Epoch 322 Loss 0.07190851867198944
# Time taken for 1 epoch 0.10526537895202637 sec
#
# Epoch 323 Batch 0 Loss 0.03542511537671089
# Epoch 323 Loss 0.07094297558069229
# Time taken for 1 epoch 0.10265302658081055 sec
#
# Epoch 324 Batch 0 Loss 0.032087381929159164
# Epoch 324 Loss 0.0674901232123375
# Time taken for 1 epoch 0.10633730888366699 sec
#
# Epoch 325 Batch 0 Loss 0.03424863517284393
# Epoch 325 Loss 0.07476246356964111
# Time taken for 1 epoch 0.15313386917114258 sec
#
# Epoch 326 Batch 0 Loss 0.03563140332698822
# Epoch 326 Loss 0.07371898740530014
# Time taken for 1 epoch 0.11623024940490723 sec
#
# Epoch 327 Batch 0 Loss 0.03492243215441704
# Epoch 327 Loss 0.06436571478843689
# Time taken for 1 epoch 0.11058282852172852 sec
#
# Epoch 328 Batch 0 Loss 0.0352427139878273
# Epoch 328 Loss 0.07159510254859924
# Time taken for 1 epoch 0.11100959777832031 sec
#
# Epoch 329 Batch 0 Loss 0.03554140403866768
# Epoch 329 Loss 0.07424726337194443
# Time taken for 1 epoch 0.11474370956420898 sec
#
# Epoch 330 Batch 0 Loss 0.03618110343813896
# Epoch 330 Loss 0.0675140842795372
# Time taken for 1 epoch 0.14578723907470703 sec
#
# Epoch 331 Batch 0 Loss 0.034857701510190964
# Epoch 331 Loss 0.06976581364870071
# Time taken for 1 epoch 0.10547709465026855 sec
#
# Epoch 332 Batch 0 Loss 0.03305190056562424
# Epoch 332 Loss 0.07302936911582947
# Time taken for 1 epoch 0.12570929527282715 sec
#
# Epoch 333 Batch 0 Loss 0.034215472638607025
# Epoch 333 Loss 0.0763203352689743
# Time taken for 1 epoch 0.12777161598205566 sec
#
# Epoch 334 Batch 0 Loss 0.03350578621029854
# Epoch 334 Loss 0.07091505080461502
# Time taken for 1 epoch 0.11484599113464355 sec
#
# Epoch 335 Batch 0 Loss 0.03389286994934082
# Epoch 335 Loss 0.07127191126346588
# Time taken for 1 epoch 0.14905714988708496 sec
#
# Epoch 336 Batch 0 Loss 0.03431178629398346
# Epoch 336 Loss 0.06732263416051865
# Time taken for 1 epoch 0.11081695556640625 sec
#
# Epoch 337 Batch 0 Loss 0.035360030829906464
# Epoch 337 Loss 0.07027780264616013
# Time taken for 1 epoch 0.1071021556854248 sec
#
# Epoch 338 Batch 0 Loss 0.03448872268199921
# Epoch 338 Loss 0.0693138912320137
# Time taken for 1 epoch 0.10355973243713379 sec
#
# Epoch 339 Batch 0 Loss 0.03406272083520889
# Epoch 339 Loss 0.07575416564941406
# Time taken for 1 epoch 0.10181260108947754 sec
#
# Epoch 340 Batch 0 Loss 0.03455334156751633
# Epoch 340 Loss 0.07277461886405945
# Time taken for 1 epoch 0.13654589653015137 sec
#
# Epoch 341 Batch 0 Loss 0.03393777459859848
# Epoch 341 Loss 0.06290017813444138
# Time taken for 1 epoch 0.10067343711853027 sec
#
# Epoch 342 Batch 0 Loss 0.035770483314991
# Epoch 342 Loss 0.07024706155061722
# Time taken for 1 epoch 0.10842609405517578 sec
#
# Epoch 343 Batch 0 Loss 0.033774830400943756
# Epoch 343 Loss 0.06218507140874863
# Time taken for 1 epoch 0.10246968269348145 sec
#
# Epoch 344 Batch 0 Loss 0.033478304743766785
# Epoch 344 Loss 0.06922917068004608
# Time taken for 1 epoch 0.10424995422363281 sec
#
# Epoch 345 Batch 0 Loss 0.03300436958670616
# Epoch 345 Loss 0.06677296757698059
# Time taken for 1 epoch 0.13551783561706543 sec
#
# Epoch 346 Batch 0 Loss 0.03297848999500275
# Epoch 346 Loss 0.06333553045988083
# Time taken for 1 epoch 0.10935068130493164 sec
#
# Epoch 347 Batch 0 Loss 0.03622318431735039
# Epoch 347 Loss 0.06964408606290817
# Time taken for 1 epoch 0.10909867286682129 sec
#
# Epoch 348 Batch 0 Loss 0.03303537890315056
# Epoch 348 Loss 0.06950783729553223
# Time taken for 1 epoch 0.10947132110595703 sec
#
# Epoch 349 Batch 0 Loss 0.03350447490811348
# Epoch 349 Loss 0.06743612885475159
# Time taken for 1 epoch 0.10494399070739746 sec
#
# Epoch 350 Batch 0 Loss 0.03179812803864479
# Epoch 350 Loss 0.0751190185546875
# Time taken for 1 epoch 0.14168930053710938 sec
#
# Epoch 351 Batch 0 Loss 0.035009611397981644
# Epoch 351 Loss 0.061106834560632706
# Time taken for 1 epoch 0.11400151252746582 sec
#
# Epoch 352 Batch 0 Loss 0.03398020565509796
# Epoch 352 Loss 0.07156781107187271
# Time taken for 1 epoch 0.11067485809326172 sec
#
# Epoch 353 Batch 0 Loss 0.03470413759350777
# Epoch 353 Loss 0.06718464195728302
# Time taken for 1 epoch 0.10740470886230469 sec
#
# Epoch 354 Batch 0 Loss 0.033131327480077744
# Epoch 354 Loss 0.06624270975589752
# Time taken for 1 epoch 0.10803461074829102 sec
#
# Epoch 355 Batch 0 Loss 0.03281570225954056
# Epoch 355 Loss 0.06227850914001465
# Time taken for 1 epoch 0.1368105411529541 sec
#
# Epoch 356 Batch 0 Loss 0.030673112720251083
# Epoch 356 Loss 0.06594953685998917
# Time taken for 1 epoch 0.11007070541381836 sec
#
# Epoch 357 Batch 0 Loss 0.0327836312353611
# Epoch 357 Loss 0.06886689364910126
# Time taken for 1 epoch 0.10639810562133789 sec
#
# Epoch 358 Batch 0 Loss 0.034319594502449036
# Epoch 358 Loss 0.06678527593612671
# Time taken for 1 epoch 0.10359001159667969 sec
#
# Epoch 359 Batch 0 Loss 0.03238166123628616
# Epoch 359 Loss 0.06463935971260071
# Time taken for 1 epoch 0.1029963493347168 sec
#
# Epoch 360 Batch 0 Loss 0.03215431049466133
# Epoch 360 Loss 0.07005343586206436
# Time taken for 1 epoch 0.15181970596313477 sec
#
# Epoch 361 Batch 0 Loss 0.03337486460804939
# Epoch 361 Loss 0.0605231337249279
# Time taken for 1 epoch 0.138261079788208 sec
#
# Epoch 362 Batch 0 Loss 0.03218068927526474
# Epoch 362 Loss 0.06092878431081772
# Time taken for 1 epoch 0.10692954063415527 sec
#
# Epoch 363 Batch 0 Loss 0.03149504214525223
# Epoch 363 Loss 0.06545893102884293
# Time taken for 1 epoch 0.10241079330444336 sec
#
# Epoch 364 Batch 0 Loss 0.03318270295858383
# Epoch 364 Loss 0.05942977964878082
# Time taken for 1 epoch 0.10779738426208496 sec
#
# Epoch 365 Batch 0 Loss 0.034325264394283295
# Epoch 365 Loss 0.06477668881416321
# Time taken for 1 epoch 0.17969322204589844 sec
#
# Epoch 366 Batch 0 Loss 0.0324651300907135
# Epoch 366 Loss 0.06531582027673721
# Time taken for 1 epoch 0.11798977851867676 sec
#
# Epoch 367 Batch 0 Loss 0.0317513607442379
# Epoch 367 Loss 0.06210082396864891
# Time taken for 1 epoch 0.11988234519958496 sec
#
# Epoch 368 Batch 0 Loss 0.032964713871479034
# Epoch 368 Loss 0.0651545524597168
# Time taken for 1 epoch 0.12209105491638184 sec
#
# Epoch 369 Batch 0 Loss 0.032463569194078445
# Epoch 369 Loss 0.06424574553966522
# Time taken for 1 epoch 0.11892151832580566 sec
#
# Epoch 370 Batch 0 Loss 0.030370021238923073
# Epoch 370 Loss 0.06768804788589478
# Time taken for 1 epoch 0.17069530487060547 sec
#
# Epoch 371 Batch 0 Loss 0.03225450962781906
# Epoch 371 Loss 0.0596003532409668
# Time taken for 1 epoch 0.12727737426757812 sec
#
# Epoch 372 Batch 0 Loss 0.033410023897886276
# Epoch 372 Loss 0.06847728043794632
# Time taken for 1 epoch 0.10476183891296387 sec
#
# Epoch 373 Batch 0 Loss 0.03150855004787445
# Epoch 373 Loss 0.06671379506587982
# Time taken for 1 epoch 0.11197423934936523 sec
#
# Epoch 374 Batch 0 Loss 0.03076706826686859
# Epoch 374 Loss 0.06500934809446335
# Time taken for 1 epoch 0.10445499420166016 sec
#
# Epoch 375 Batch 0 Loss 0.032042957842350006
# Epoch 375 Loss 0.06292536109685898
# Time taken for 1 epoch 0.14043593406677246 sec
#
# Epoch 376 Batch 0 Loss 0.031620822846889496
# Epoch 376 Loss 0.05937212333083153
# Time taken for 1 epoch 0.11424064636230469 sec
#
# Epoch 377 Batch 0 Loss 0.03158164396882057
# Epoch 377 Loss 0.06513328105211258
# Time taken for 1 epoch 0.10332965850830078 sec
#
# Epoch 378 Batch 0 Loss 0.030354386195540428
# Epoch 378 Loss 0.059272609651088715
# Time taken for 1 epoch 0.10513997077941895 sec
#
# Epoch 379 Batch 0 Loss 0.03236754238605499
# Epoch 379 Loss 0.05798467993736267
# Time taken for 1 epoch 0.10671830177307129 sec
#
# Epoch 380 Batch 0 Loss 0.03166602924466133
# Epoch 380 Loss 0.06283776462078094
# Time taken for 1 epoch 0.13539338111877441 sec
#
# Epoch 381 Batch 0 Loss 0.030932769179344177
# Epoch 381 Loss 0.0577922947704792
# Time taken for 1 epoch 0.11297726631164551 sec
#
# Epoch 382 Batch 0 Loss 0.03231155872344971
# Epoch 382 Loss 0.06501862406730652
# Time taken for 1 epoch 0.10678815841674805 sec
#
# Epoch 383 Batch 0 Loss 0.03327498957514763
# Epoch 383 Loss 0.057098742574453354
# Time taken for 1 epoch 0.10868096351623535 sec
#
# Epoch 384 Batch 0 Loss 0.030312281101942062
# Epoch 384 Loss 0.06276966631412506
# Time taken for 1 epoch 0.11364459991455078 sec
#
# Epoch 385 Batch 0 Loss 0.03305843472480774
# Epoch 385 Loss 0.06436756998300552
# Time taken for 1 epoch 0.13543295860290527 sec
#
# Epoch 386 Batch 0 Loss 0.03197694197297096
# Epoch 386 Loss 0.06544787436723709
# Time taken for 1 epoch 0.11920571327209473 sec
#
# Epoch 387 Batch 0 Loss 0.03008069470524788
# Epoch 387 Loss 0.06626872718334198
# Time taken for 1 epoch 0.11834096908569336 sec
#
# Epoch 388 Batch 0 Loss 0.033296845853328705
# Epoch 388 Loss 0.0636240541934967
# Time taken for 1 epoch 0.12065410614013672 sec
#
# Epoch 389 Batch 0 Loss 0.030849412083625793
# Epoch 389 Loss 0.057583797723054886
# Time taken for 1 epoch 0.10782694816589355 sec
#
# Epoch 390 Batch 0 Loss 0.033600691705942154
# Epoch 390 Loss 0.05831664055585861
# Time taken for 1 epoch 0.14555621147155762 sec
#
# Epoch 391 Batch 0 Loss 0.03076849691569805
# Epoch 391 Loss 0.06892932206392288
# Time taken for 1 epoch 0.1210176944732666 sec
#
# Epoch 392 Batch 0 Loss 0.03086980991065502
# Epoch 392 Loss 0.05732106789946556
# Time taken for 1 epoch 0.11606478691101074 sec
#
# Epoch 393 Batch 0 Loss 0.03213106468319893
# Epoch 393 Loss 0.06247708201408386
# Time taken for 1 epoch 0.1315782070159912 sec
#
# Epoch 394 Batch 0 Loss 0.031212106347084045
# Epoch 394 Loss 0.062139157205820084
# Time taken for 1 epoch 0.11279106140136719 sec
#
# Epoch 395 Batch 0 Loss 0.03048253245651722
# Epoch 395 Loss 0.06718394160270691
# Time taken for 1 epoch 0.1408374309539795 sec
#
# Epoch 396 Batch 0 Loss 0.03286111354827881
# Epoch 396 Loss 0.058934830129146576
# Time taken for 1 epoch 0.10593414306640625 sec
#
# Epoch 397 Batch 0 Loss 0.03193576633930206
# Epoch 397 Loss 0.05799423158168793
# Time taken for 1 epoch 0.12796330451965332 sec
#
# Epoch 398 Batch 0 Loss 0.03359946236014366
# Epoch 398 Loss 0.05848654732108116
# Time taken for 1 epoch 0.12402820587158203 sec
#
# Epoch 399 Batch 0 Loss 0.03126382827758789
# Epoch 399 Loss 0.06076515093445778
# Time taken for 1 epoch 0.11569476127624512 sec
#
# Epoch 400 Batch 0 Loss 0.03266201168298721
# Epoch 400 Loss 0.06726809591054916
# Time taken for 1 epoch 0.13910150527954102 sec
#
# Epoch 401 Batch 0 Loss 0.031094755977392197
# Epoch 401 Loss 0.060096826404333115
# Time taken for 1 epoch 0.11150002479553223 sec
#
# Epoch 402 Batch 0 Loss 0.030526533722877502
# Epoch 402 Loss 0.05963318049907684
# Time taken for 1 epoch 0.10103154182434082 sec
#
# Epoch 403 Batch 0 Loss 0.030840501189231873
# Epoch 403 Loss 0.05992322042584419
# Time taken for 1 epoch 0.10456466674804688 sec
#
# Epoch 404 Batch 0 Loss 0.031128786504268646
# Epoch 404 Loss 0.060518961399793625
# Time taken for 1 epoch 0.11147212982177734 sec
#
# Epoch 405 Batch 0 Loss 0.03362134471535683
# Epoch 405 Loss 0.07005203515291214
# Time taken for 1 epoch 0.1791069507598877 sec
#
# Epoch 406 Batch 0 Loss 0.03301016986370087
# Epoch 406 Loss 0.06030783802270889
# Time taken for 1 epoch 0.12934589385986328 sec
#
# Epoch 407 Batch 0 Loss 0.032360177487134933
# Epoch 407 Loss 0.0639839842915535
# Time taken for 1 epoch 0.1079719066619873 sec
#
# Epoch 408 Batch 0 Loss 0.02995935268700123
# Epoch 408 Loss 0.05612776800990105
# Time taken for 1 epoch 0.1124875545501709 sec
#
# Epoch 409 Batch 0 Loss 0.0314517468214035
# Epoch 409 Loss 0.05676967650651932
# Time taken for 1 epoch 0.10587716102600098 sec
#
# Epoch 410 Batch 0 Loss 0.03072652965784073
# Epoch 410 Loss 0.0638364776968956
# Time taken for 1 epoch 0.15769028663635254 sec
#
# Epoch 411 Batch 0 Loss 0.03194427117705345
# Epoch 411 Loss 0.05714016035199165
# Time taken for 1 epoch 0.11023068428039551 sec
#
# Epoch 412 Batch 0 Loss 0.030495667830109596
# Epoch 412 Loss 0.057346686720848083
# Time taken for 1 epoch 0.1071321964263916 sec
#
# Epoch 413 Batch 0 Loss 0.03047044761478901
# Epoch 413 Loss 0.06235504150390625
# Time taken for 1 epoch 0.10648393630981445 sec
#
# Epoch 414 Batch 0 Loss 0.032446883618831635
# Epoch 414 Loss 0.06093856692314148
# Time taken for 1 epoch 0.1037294864654541 sec
#
# Epoch 415 Batch 0 Loss 0.030447395518422127
# Epoch 415 Loss 0.05257157236337662
# Time taken for 1 epoch 0.1547856330871582 sec
#
# Epoch 416 Batch 0 Loss 0.03138694912195206
# Epoch 416 Loss 0.06099836900830269
# Time taken for 1 epoch 0.11177515983581543 sec
#
# Epoch 417 Batch 0 Loss 0.030029144138097763
# Epoch 417 Loss 0.05623745918273926
# Time taken for 1 epoch 0.11193466186523438 sec
#
# Epoch 418 Batch 0 Loss 0.03020615503191948
# Epoch 418 Loss 0.052996158599853516
# Time taken for 1 epoch 0.11758160591125488 sec
#
# Epoch 419 Batch 0 Loss 0.02969774790108204
# Epoch 419 Loss 0.05623415857553482
# Time taken for 1 epoch 0.11421751976013184 sec
#
# Epoch 420 Batch 0 Loss 0.031205758452415466
# Epoch 420 Loss 0.05717948079109192
# Time taken for 1 epoch 0.13419628143310547 sec
#
# Epoch 421 Batch 0 Loss 0.03125598281621933
# Epoch 421 Loss 0.06134067475795746
# Time taken for 1 epoch 0.10352706909179688 sec
#
# Epoch 422 Batch 0 Loss 0.031863197684288025
# Epoch 422 Loss 0.0589371882379055
# Time taken for 1 epoch 0.10992074012756348 sec
#
# Epoch 423 Batch 0 Loss 0.031033983454108238
# Epoch 423 Loss 0.054985132068395615
# Time taken for 1 epoch 0.12290501594543457 sec
#
# Epoch 424 Batch 0 Loss 0.03170439973473549
# Epoch 424 Loss 0.05259866639971733
# Time taken for 1 epoch 0.12098932266235352 sec
#
# Epoch 425 Batch 0 Loss 0.031100593507289886
# Epoch 425 Loss 0.05169311910867691
# Time taken for 1 epoch 0.15244388580322266 sec
#
# Epoch 426 Batch 0 Loss 0.031346701085567474
# Epoch 426 Loss 0.05949225276708603
# Time taken for 1 epoch 0.11569404602050781 sec
#
# Epoch 427 Batch 0 Loss 0.031364936381578445
# Epoch 427 Loss 0.06276301294565201
# Time taken for 1 epoch 0.10343480110168457 sec
#
# Epoch 428 Batch 0 Loss 0.030262155458331108
# Epoch 428 Loss 0.06587737798690796
# Time taken for 1 epoch 0.10272336006164551 sec
#
# Epoch 429 Batch 0 Loss 0.028130851686000824
# Epoch 429 Loss 0.06000730022788048
# Time taken for 1 epoch 0.10421252250671387 sec
#
# Epoch 430 Batch 0 Loss 0.029951710253953934
# Epoch 430 Loss 0.059964656829833984
# Time taken for 1 epoch 0.13663005828857422 sec
#
# Epoch 431 Batch 0 Loss 0.03164415434002876
# Epoch 431 Loss 0.0594170056283474
# Time taken for 1 epoch 0.10711836814880371 sec
#
# Epoch 432 Batch 0 Loss 0.02893640473484993
# Epoch 432 Loss 0.06366083025932312
# Time taken for 1 epoch 0.10025501251220703 sec
#
# Epoch 433 Batch 0 Loss 0.0291697159409523
# Epoch 433 Loss 0.06077820807695389
# Time taken for 1 epoch 0.1019432544708252 sec
#
# Epoch 434 Batch 0 Loss 0.03084600530564785
# Epoch 434 Loss 0.055999308824539185
# Time taken for 1 epoch 0.11039280891418457 sec
#
# Epoch 435 Batch 0 Loss 0.03140293434262276
# Epoch 435 Loss 0.06040164455771446
# Time taken for 1 epoch 0.13785481452941895 sec
#
# Epoch 436 Batch 0 Loss 0.033584240823984146
# Epoch 436 Loss 0.05245976522564888
# Time taken for 1 epoch 0.1058950424194336 sec
#
# Epoch 437 Batch 0 Loss 0.02906023897230625
# Epoch 437 Loss 0.05310613662004471
# Time taken for 1 epoch 0.10298585891723633 sec
#
# Epoch 438 Batch 0 Loss 0.031599946320056915
# Epoch 438 Loss 0.047833651304244995
# Time taken for 1 epoch 0.10784697532653809 sec
#
# Epoch 439 Batch 0 Loss 0.02824332006275654
# Epoch 439 Loss 0.061988331377506256
# Time taken for 1 epoch 0.10210204124450684 sec
#
# Epoch 440 Batch 0 Loss 0.030684836208820343
# Epoch 440 Loss 0.05219975858926773
# Time taken for 1 epoch 0.13920879364013672 sec
#
# Epoch 441 Batch 0 Loss 0.030508117750287056
# Epoch 441 Loss 0.05998820438981056
# Time taken for 1 epoch 0.11154961585998535 sec
#
# Epoch 442 Batch 0 Loss 0.03039386309683323
# Epoch 442 Loss 0.05422033369541168
# Time taken for 1 epoch 0.10708379745483398 sec
#
# Epoch 443 Batch 0 Loss 0.03089587204158306
# Epoch 443 Loss 0.05333452299237251
# Time taken for 1 epoch 0.1072690486907959 sec
#
# Epoch 444 Batch 0 Loss 0.03158259391784668
# Epoch 444 Loss 0.05697633698582649
# Time taken for 1 epoch 0.10579156875610352 sec
#
# Epoch 445 Batch 0 Loss 0.03013991378247738
# Epoch 445 Loss 0.06426389515399933
# Time taken for 1 epoch 0.13663935661315918 sec
#
# Epoch 446 Batch 0 Loss 0.029684295877814293
# Epoch 446 Loss 0.05315657705068588
# Time taken for 1 epoch 0.10319042205810547 sec
#
# Epoch 447 Batch 0 Loss 0.02933472953736782
# Epoch 447 Loss 0.05849386379122734
# Time taken for 1 epoch 0.10374736785888672 sec
#
# Epoch 448 Batch 0 Loss 0.029848413541913033
# Epoch 448 Loss 0.05575285106897354
# Time taken for 1 epoch 0.10297203063964844 sec
#
# Epoch 449 Batch 0 Loss 0.031133538112044334
# Epoch 449 Loss 0.05436696484684944
# Time taken for 1 epoch 0.1153252124786377 sec
#
# Epoch 450 Batch 0 Loss 0.028247231617569923
# Epoch 450 Loss 0.05142023041844368
# Time taken for 1 epoch 0.24872088432312012 sec
#
# Epoch 451 Batch 0 Loss 0.02830374240875244
# Epoch 451 Loss 0.05861445516347885
# Time taken for 1 epoch 0.12711238861083984 sec
#
# Epoch 452 Batch 0 Loss 0.030442815274000168
# Epoch 452 Loss 0.054349713027477264
# Time taken for 1 epoch 0.12372636795043945 sec
#
# Epoch 453 Batch 0 Loss 0.029259834438562393
# Epoch 453 Loss 0.059801045805215836
# Time taken for 1 epoch 0.11690235137939453 sec
#
# Epoch 454 Batch 0 Loss 0.028722653165459633
# Epoch 454 Loss 0.05525893718004227
# Time taken for 1 epoch 0.10132837295532227 sec
#
# Epoch 455 Batch 0 Loss 0.030476603657007217
# Epoch 455 Loss 0.05482585355639458
# Time taken for 1 epoch 0.15297436714172363 sec
#
# Epoch 456 Batch 0 Loss 0.03138163685798645
# Epoch 456 Loss 0.05379100888967514
# Time taken for 1 epoch 0.10452866554260254 sec
#
# Epoch 457 Batch 0 Loss 0.0313786156475544
# Epoch 457 Loss 0.05631061643362045
# Time taken for 1 epoch 0.10379528999328613 sec
#
# Epoch 458 Batch 0 Loss 0.02959189936518669
# Epoch 458 Loss 0.058041974902153015
# Time taken for 1 epoch 0.10460948944091797 sec
#
# Epoch 459 Batch 0 Loss 0.030975760892033577
# Epoch 459 Loss 0.05478741601109505
# Time taken for 1 epoch 0.10914444923400879 sec
#
# Epoch 460 Batch 0 Loss 0.02994919754564762
# Epoch 460 Loss 0.05425410345196724
# Time taken for 1 epoch 0.14747214317321777 sec
#
# Epoch 461 Batch 0 Loss 0.030425719916820526
# Epoch 461 Loss 0.05191097408533096
# Time taken for 1 epoch 0.11864328384399414 sec
#
# Epoch 462 Batch 0 Loss 0.03117194212973118
# Epoch 462 Loss 0.05767587199807167
# Time taken for 1 epoch 0.10932612419128418 sec
#
# Epoch 463 Batch 0 Loss 0.029115738347172737
# Epoch 463 Loss 0.0526035837829113
# Time taken for 1 epoch 0.10863232612609863 sec
#
# Epoch 464 Batch 0 Loss 0.029970798641443253
# Epoch 464 Loss 0.050109658390283585
# Time taken for 1 epoch 0.1146242618560791 sec
#
# Epoch 465 Batch 0 Loss 0.02894345112144947
# Epoch 465 Loss 0.048725128173828125
# Time taken for 1 epoch 0.1434934139251709 sec
#
# Epoch 466 Batch 0 Loss 0.03148629888892174
# Epoch 466 Loss 0.04804952070116997
# Time taken for 1 epoch 0.10570883750915527 sec
#
# Epoch 467 Batch 0 Loss 0.02972731553018093
# Epoch 467 Loss 0.04881926625967026
# Time taken for 1 epoch 0.10331940650939941 sec
#
# Epoch 468 Batch 0 Loss 0.029569609090685844
# Epoch 468 Loss 0.05583825707435608
# Time taken for 1 epoch 0.1119987964630127 sec
#
# Epoch 469 Batch 0 Loss 0.029961789026856422
# Epoch 469 Loss 0.055160705000162125
# Time taken for 1 epoch 0.10664582252502441 sec
#
# Epoch 470 Batch 0 Loss 0.03146138787269592
# Epoch 470 Loss 0.05144917592406273
# Time taken for 1 epoch 0.14818668365478516 sec
#
# Epoch 471 Batch 0 Loss 0.0295069832354784
# Epoch 471 Loss 0.05639973282814026
# Time taken for 1 epoch 0.11131429672241211 sec
#
# Epoch 472 Batch 0 Loss 0.03116472065448761
# Epoch 472 Loss 0.04890423268079758
# Time taken for 1 epoch 0.10345935821533203 sec
#
# Epoch 473 Batch 0 Loss 0.02844228781759739
# Epoch 473 Loss 0.05293755233287811
# Time taken for 1 epoch 0.10956048965454102 sec
#
# Epoch 474 Batch 0 Loss 0.030274562537670135
# Epoch 474 Loss 0.05242682993412018
# Time taken for 1 epoch 0.10635972023010254 sec
#
# Epoch 475 Batch 0 Loss 0.0290337186306715
# Epoch 475 Loss 0.0460740365087986
# Time taken for 1 epoch 0.13837575912475586 sec
#
# Epoch 476 Batch 0 Loss 0.028619997203350067
# Epoch 476 Loss 0.05091242492198944
# Time taken for 1 epoch 0.11639714241027832 sec
#
# Epoch 477 Batch 0 Loss 0.029819341376423836
# Epoch 477 Loss 0.05500879883766174
# Time taken for 1 epoch 0.11430025100708008 sec
#
# Epoch 478 Batch 0 Loss 0.028300590813159943
# Epoch 478 Loss 0.056221410632133484
# Time taken for 1 epoch 0.10957098007202148 sec
#
# Epoch 479 Batch 0 Loss 0.0286003015935421
# Epoch 479 Loss 0.059228017926216125
# Time taken for 1 epoch 0.10555410385131836 sec
#
# Epoch 480 Batch 0 Loss 0.029187344014644623
# Epoch 480 Loss 0.05312366411089897
# Time taken for 1 epoch 0.13467955589294434 sec
#
# Epoch 481 Batch 0 Loss 0.03071649558842182
# Epoch 481 Loss 0.05032554268836975
# Time taken for 1 epoch 0.12091612815856934 sec
#
# Epoch 482 Batch 0 Loss 0.02877078950405121
# Epoch 482 Loss 0.055003948509693146
# Time taken for 1 epoch 0.10782074928283691 sec
#
# Epoch 483 Batch 0 Loss 0.03106261044740677
# Epoch 483 Loss 0.057486239820718765
# Time taken for 1 epoch 0.11892342567443848 sec
#
# Epoch 484 Batch 0 Loss 0.030748266726732254
# Epoch 484 Loss 0.05435806140303612
# Time taken for 1 epoch 0.11794519424438477 sec
#
# Epoch 485 Batch 0 Loss 0.029372215270996094
# Epoch 485 Loss 0.05535898357629776
# Time taken for 1 epoch 0.15847039222717285 sec
#
# Epoch 486 Batch 0 Loss 0.028643732890486717
# Epoch 486 Loss 0.05424438416957855
# Time taken for 1 epoch 0.12162303924560547 sec
#
# Epoch 487 Batch 0 Loss 0.029418086633086205
# Epoch 487 Loss 0.05391227826476097
# Time taken for 1 epoch 0.11547708511352539 sec
#
# Epoch 488 Batch 0 Loss 0.030028071254491806
# Epoch 488 Loss 0.05954107269644737
# Time taken for 1 epoch 0.10657525062561035 sec
#
# Epoch 489 Batch 0 Loss 0.029249543324112892
# Epoch 489 Loss 0.05605386570096016
# Time taken for 1 epoch 0.1082606315612793 sec
#
# Epoch 490 Batch 0 Loss 0.030658597126603127
# Epoch 490 Loss 0.05199550464749336
# Time taken for 1 epoch 0.1371932029724121 sec
#
# Epoch 491 Batch 0 Loss 0.028023598715662956
# Epoch 491 Loss 0.056517768651247025
# Time taken for 1 epoch 0.10582661628723145 sec
#
# Epoch 492 Batch 0 Loss 0.028600340709090233
# Epoch 492 Loss 0.0509638674557209
# Time taken for 1 epoch 0.11130762100219727 sec
#
# Epoch 493 Batch 0 Loss 0.031258128583431244
# Epoch 493 Loss 0.051918551325798035
# Time taken for 1 epoch 0.11087417602539062 sec
#
# Epoch 494 Batch 0 Loss 0.029202310368418694
# Epoch 494 Loss 0.05530410632491112
# Time taken for 1 epoch 0.11030030250549316 sec
#
# Epoch 495 Batch 0 Loss 0.030629942193627357
# Epoch 495 Loss 0.055880699306726456
# Time taken for 1 epoch 0.17655134201049805 sec
#
# Epoch 496 Batch 0 Loss 0.02940450608730316
# Epoch 496 Loss 0.05866902321577072
# Time taken for 1 epoch 0.15749669075012207 sec
#
# Epoch 497 Batch 0 Loss 0.02941875532269478
# Epoch 497 Loss 0.050464361906051636
# Time taken for 1 epoch 0.10845518112182617 sec
#
# Epoch 498 Batch 0 Loss 0.03103523887693882
# Epoch 498 Loss 0.06079695746302605
# Time taken for 1 epoch 0.10427045822143555 sec
#
# Epoch 499 Batch 0 Loss 0.031217779964208603
# Epoch 499 Loss 0.04845874011516571
# Time taken for 1 epoch 0.10997152328491211 sec
#
# Epoch 500 Batch 0 Loss 0.02939191833138466
# Epoch 500 Loss 0.05000840127468109
# Time taken for 1 epoch 0.16427850723266602 sec
#
# Epoch 501 Batch 0 Loss 0.029769720509648323
# Epoch 501 Loss 0.05255734547972679
# Time taken for 1 epoch 0.1136922836303711 sec
#
# Epoch 502 Batch 0 Loss 0.02998596616089344
# Epoch 502 Loss 0.05047168582677841
# Time taken for 1 epoch 0.10722780227661133 sec
#
# Epoch 503 Batch 0 Loss 0.029012134298682213
# Epoch 503 Loss 0.05774717405438423
# Time taken for 1 epoch 0.11189699172973633 sec
#
# Epoch 504 Batch 0 Loss 0.03078300692141056
# Epoch 504 Loss 0.04850423336029053
# Time taken for 1 epoch 0.10837864875793457 sec
#
# Epoch 505 Batch 0 Loss 0.03220820799469948
# Epoch 505 Loss 0.05378164350986481
# Time taken for 1 epoch 0.1650683879852295 sec
#
# Epoch 506 Batch 0 Loss 0.029149556532502174
# Epoch 506 Loss 0.04465925693511963
# Time taken for 1 epoch 0.12902188301086426 sec
#
# Epoch 507 Batch 0 Loss 0.028219113126397133
# Epoch 507 Loss 0.05240236222743988
# Time taken for 1 epoch 0.13301610946655273 sec
#
# Epoch 508 Batch 0 Loss 0.03108241781592369
# Epoch 508 Loss 0.05096421390771866
# Time taken for 1 epoch 0.12119126319885254 sec
#
# Epoch 509 Batch 0 Loss 0.027951179072260857
# Epoch 509 Loss 0.05173841491341591
# Time taken for 1 epoch 0.1258525848388672 sec
#
# Epoch 510 Batch 0 Loss 0.03053174540400505
# Epoch 510 Loss 0.054932594299316406
# Time taken for 1 epoch 0.14534974098205566 sec
#
# Epoch 511 Batch 0 Loss 0.0298471599817276
# Epoch 511 Loss 0.049552079290151596
# Time taken for 1 epoch 0.13299894332885742 sec
#
# Epoch 512 Batch 0 Loss 0.030222205445170403
# Epoch 512 Loss 0.046793680638074875
# Time taken for 1 epoch 0.11953449249267578 sec
#
# Epoch 513 Batch 0 Loss 0.030979327857494354
# Epoch 513 Loss 0.0508929006755352
# Time taken for 1 epoch 0.1199030876159668 sec
#
# Epoch 514 Batch 0 Loss 0.029949113726615906
# Epoch 514 Loss 0.04762223735451698
# Time taken for 1 epoch 0.12085580825805664 sec
#
# Epoch 515 Batch 0 Loss 0.02872690185904503
# Epoch 515 Loss 0.04798640310764313
# Time taken for 1 epoch 0.160048246383667 sec
#
# Epoch 516 Batch 0 Loss 0.02830634079873562
# Epoch 516 Loss 0.04997473210096359
# Time taken for 1 epoch 0.12431669235229492 sec
#
# Epoch 517 Batch 0 Loss 0.030005015432834625
# Epoch 517 Loss 0.04747988283634186
# Time taken for 1 epoch 0.11682748794555664 sec
#
# Epoch 518 Batch 0 Loss 0.029464388266205788
# Epoch 518 Loss 0.0509398989379406
# Time taken for 1 epoch 0.12545275688171387 sec
#
# Epoch 519 Batch 0 Loss 0.028235701844096184
# Epoch 519 Loss 0.0484476312994957
# Time taken for 1 epoch 0.12544918060302734 sec
#
# Epoch 520 Batch 0 Loss 0.02965703420341015
# Epoch 520 Loss 0.0540044941008091
# Time taken for 1 epoch 0.13929486274719238 sec
#
# Epoch 521 Batch 0 Loss 0.02841676026582718
# Epoch 521 Loss 0.047094885259866714
# Time taken for 1 epoch 0.10908174514770508 sec
#
# Epoch 522 Batch 0 Loss 0.029813824221491814
# Epoch 522 Loss 0.05573137104511261
# Time taken for 1 epoch 0.10483455657958984 sec
#
# Epoch 523 Batch 0 Loss 0.028424663469195366
# Epoch 523 Loss 0.05494026839733124
# Time taken for 1 epoch 0.10230016708374023 sec
#
# Epoch 524 Batch 0 Loss 0.03009006194770336
# Epoch 524 Loss 0.04849370941519737
# Time taken for 1 epoch 0.10853147506713867 sec
#
# Epoch 525 Batch 0 Loss 0.027998752892017365
# Epoch 525 Loss 0.04228341579437256
# Time taken for 1 epoch 0.143707275390625 sec
#
# Epoch 526 Batch 0 Loss 0.025927124544978142
# Epoch 526 Loss 0.05238538607954979
# Time taken for 1 epoch 0.1114664077758789 sec
#
# Epoch 527 Batch 0 Loss 0.02861071564257145
# Epoch 527 Loss 0.04817210137844086
# Time taken for 1 epoch 0.10782551765441895 sec
#
# Epoch 528 Batch 0 Loss 0.027733149006962776
# Epoch 528 Loss 0.0485256165266037
# Time taken for 1 epoch 0.1104130744934082 sec
#
# Epoch 529 Batch 0 Loss 0.027927951887249947
# Epoch 529 Loss 0.04947267472743988
# Time taken for 1 epoch 0.1097879409790039 sec
#
# Epoch 530 Batch 0 Loss 0.027399031445384026
# Epoch 530 Loss 0.04924537241458893
# Time taken for 1 epoch 0.148787260055542 sec
#
# Epoch 531 Batch 0 Loss 0.027741560712456703
# Epoch 531 Loss 0.04954288527369499
# Time taken for 1 epoch 0.12343192100524902 sec
#
# Epoch 532 Batch 0 Loss 0.028227251023054123
# Epoch 532 Loss 0.04961513355374336
# Time taken for 1 epoch 0.13110661506652832 sec
#
# Epoch 533 Batch 0 Loss 0.028565507382154465
# Epoch 533 Loss 0.04959239065647125
# Time taken for 1 epoch 0.12931585311889648 sec
#
# Epoch 534 Batch 0 Loss 0.02846740186214447
# Epoch 534 Loss 0.05297829210758209
# Time taken for 1 epoch 0.1192178726196289 sec
#
# Epoch 535 Batch 0 Loss 0.02671990357339382
# Epoch 535 Loss 0.05286172777414322
# Time taken for 1 epoch 0.15063691139221191 sec
#
# Epoch 536 Batch 0 Loss 0.027489712461829185
# Epoch 536 Loss 0.04992884770035744
# Time taken for 1 epoch 0.1121828556060791 sec
#
# Epoch 537 Batch 0 Loss 0.030282940715551376
# Epoch 537 Loss 0.04889766871929169
# Time taken for 1 epoch 0.11499881744384766 sec
#
# Epoch 538 Batch 0 Loss 0.029994750395417213
# Epoch 538 Loss 0.053076375275850296
# Time taken for 1 epoch 0.1112208366394043 sec
#
# Epoch 539 Batch 0 Loss 0.02823391929268837
# Epoch 539 Loss 0.04694196581840515
# Time taken for 1 epoch 0.13285613059997559 sec
#
# Epoch 540 Batch 0 Loss 0.029639923945069313
# Epoch 540 Loss 0.04913445562124252
# Time taken for 1 epoch 0.229170560836792 sec
#
# Epoch 541 Batch 0 Loss 0.02869957685470581
# Epoch 541 Loss 0.04966529831290245
# Time taken for 1 epoch 0.15224218368530273 sec
#
# Epoch 542 Batch 0 Loss 0.02870183065533638
# Epoch 542 Loss 0.04838547855615616
# Time taken for 1 epoch 0.1270744800567627 sec
#
# Epoch 543 Batch 0 Loss 0.027186283841729164
# Epoch 543 Loss 0.05202418193221092
# Time taken for 1 epoch 0.13834857940673828 sec
#
# Epoch 544 Batch 0 Loss 0.029507316648960114
# Epoch 544 Loss 0.04740031063556671
# Time taken for 1 epoch 0.11709213256835938 sec
#
# Epoch 545 Batch 0 Loss 0.02808242291212082
# Epoch 545 Loss 0.047541294246912
# Time taken for 1 epoch 0.1607344150543213 sec
#
# Epoch 546 Batch 0 Loss 0.02710096538066864
# Epoch 546 Loss 0.049625299870967865
# Time taken for 1 epoch 0.11480069160461426 sec
#
# Epoch 547 Batch 0 Loss 0.028061941266059875
# Epoch 547 Loss 0.04756498709321022
# Time taken for 1 epoch 0.11551618576049805 sec
#
# Epoch 548 Batch 0 Loss 0.02577459253370762
# Epoch 548 Loss 0.050009164959192276
# Time taken for 1 epoch 0.13907456398010254 sec
#
# Epoch 549 Batch 0 Loss 0.028133012354373932
# Epoch 549 Loss 0.05326591432094574
# Time taken for 1 epoch 0.11755633354187012 sec
#
# Epoch 550 Batch 0 Loss 0.02697649411857128
# Epoch 550 Loss 0.0465148501098156
# Time taken for 1 epoch 0.1514286994934082 sec
#
# Epoch 551 Batch 0 Loss 0.027254324406385422
# Epoch 551 Loss 0.047130998224020004
# Time taken for 1 epoch 0.11337089538574219 sec
#
# Epoch 552 Batch 0 Loss 0.029135411605238914
# Epoch 552 Loss 0.049114227294921875
# Time taken for 1 epoch 0.12230181694030762 sec
#
# Epoch 553 Batch 0 Loss 0.02789054811000824
# Epoch 553 Loss 0.04418163746595383
# Time taken for 1 epoch 0.11645841598510742 sec
#
# Epoch 554 Batch 0 Loss 0.029690256342291832
# Epoch 554 Loss 0.048076730221509933
# Time taken for 1 epoch 0.11493134498596191 sec
#
# Epoch 555 Batch 0 Loss 0.027977464720606804
# Epoch 555 Loss 0.04932713136076927
# Time taken for 1 epoch 0.1400318145751953 sec
#
# Epoch 556 Batch 0 Loss 0.028009019792079926
# Epoch 556 Loss 0.05020071566104889
# Time taken for 1 epoch 0.11328577995300293 sec
#
# Epoch 557 Batch 0 Loss 0.02725723758339882
# Epoch 557 Loss 0.05203442648053169
# Time taken for 1 epoch 0.11449623107910156 sec
#
# Epoch 558 Batch 0 Loss 0.02809402532875538
# Epoch 558 Loss 0.05025709047913551
# Time taken for 1 epoch 0.1188967227935791 sec
#
# Epoch 559 Batch 0 Loss 0.028915369883179665
# Epoch 559 Loss 0.05082045868039131
# Time taken for 1 epoch 0.1205906867980957 sec
#
# Epoch 560 Batch 0 Loss 0.027949370443820953
# Epoch 560 Loss 0.04631548002362251
# Time taken for 1 epoch 0.14319825172424316 sec
#
# Epoch 561 Batch 0 Loss 0.026242347434163094
# Epoch 561 Loss 0.040798913687467575
# Time taken for 1 epoch 0.11014032363891602 sec
#
# Epoch 562 Batch 0 Loss 0.026989908888936043
# Epoch 562 Loss 0.049404412508010864
# Time taken for 1 epoch 0.11266613006591797 sec
#
# Epoch 563 Batch 0 Loss 0.026665840297937393
# Epoch 563 Loss 0.043590135872364044
# Time taken for 1 epoch 0.10577535629272461 sec
#
# Epoch 564 Batch 0 Loss 0.028840914368629456
# Epoch 564 Loss 0.0422341525554657
# Time taken for 1 epoch 0.1110529899597168 sec
#
# Epoch 565 Batch 0 Loss 0.02921321801841259
# Epoch 565 Loss 0.042387060821056366
# Time taken for 1 epoch 0.1405341625213623 sec
#
# Epoch 566 Batch 0 Loss 0.028788022696971893
# Epoch 566 Loss 0.04913247004151344
# Time taken for 1 epoch 0.10851740837097168 sec
#
# Epoch 567 Batch 0 Loss 0.027787771075963974
# Epoch 567 Loss 0.04707421362400055
# Time taken for 1 epoch 0.12110781669616699 sec
#
# Epoch 568 Batch 0 Loss 0.026820290833711624
# Epoch 568 Loss 0.05048639327287674
# Time taken for 1 epoch 0.11295294761657715 sec
#
# Epoch 569 Batch 0 Loss 0.030019333586096764
# Epoch 569 Loss 0.045200470834970474
# Time taken for 1 epoch 0.1268010139465332 sec
#
# Epoch 570 Batch 0 Loss 0.027441320940852165
# Epoch 570 Loss 0.046871889382600784
# Time taken for 1 epoch 0.1579298973083496 sec
#
# Epoch 571 Batch 0 Loss 0.026139473542571068
# Epoch 571 Loss 0.04477744176983833
# Time taken for 1 epoch 0.1373281478881836 sec
#
# Epoch 572 Batch 0 Loss 0.028395261615514755
# Epoch 572 Loss 0.044978197664022446
# Time taken for 1 epoch 0.12748503684997559 sec
#
# Epoch 573 Batch 0 Loss 0.02708435244858265
# Epoch 573 Loss 0.0481833890080452
# Time taken for 1 epoch 0.13348722457885742 sec
#
# Epoch 574 Batch 0 Loss 0.028629567474126816
# Epoch 574 Loss 0.044611670076847076
# Time taken for 1 epoch 0.12774920463562012 sec
#
# Epoch 575 Batch 0 Loss 0.026991385966539383
# Epoch 575 Loss 0.05407456308603287
# Time taken for 1 epoch 0.14257335662841797 sec
#
# Epoch 576 Batch 0 Loss 0.02902187593281269
# Epoch 576 Loss 0.04488161578774452
# Time taken for 1 epoch 0.11572837829589844 sec
#
# Epoch 577 Batch 0 Loss 0.028969205915927887
# Epoch 577 Loss 0.04681866616010666
# Time taken for 1 epoch 0.10839104652404785 sec
#
# Epoch 578 Batch 0 Loss 0.029226984828710556
# Epoch 578 Loss 0.04581456258893013
# Time taken for 1 epoch 0.1250476837158203 sec
#
# Epoch 579 Batch 0 Loss 0.027287587523460388
# Epoch 579 Loss 0.047639597207307816
# Time taken for 1 epoch 0.12947463989257812 sec
#
# Epoch 580 Batch 0 Loss 0.02793652005493641
# Epoch 580 Loss 0.04373550787568092
# Time taken for 1 epoch 0.16508769989013672 sec
#
# Epoch 581 Batch 0 Loss 0.02905045822262764
# Epoch 581 Loss 0.0424022451043129
# Time taken for 1 epoch 0.20609378814697266 sec
#
# Epoch 582 Batch 0 Loss 0.02792760357260704
# Epoch 582 Loss 0.04199495166540146
# Time taken for 1 epoch 0.1192467212677002 sec
#
# Epoch 583 Batch 0 Loss 0.027613287791609764
# Epoch 583 Loss 0.04604063183069229
# Time taken for 1 epoch 0.13646841049194336 sec
#
# Epoch 584 Batch 0 Loss 0.027660727500915527
# Epoch 584 Loss 0.049504250288009644
# Time taken for 1 epoch 0.11518573760986328 sec
#
# Epoch 585 Batch 0 Loss 0.028142385184764862
# Epoch 585 Loss 0.041788309812545776
# Time taken for 1 epoch 0.20931291580200195 sec
#
# Epoch 586 Batch 0 Loss 0.027691109105944633
# Epoch 586 Loss 0.04459407925605774
# Time taken for 1 epoch 0.12294864654541016 sec
#
# Epoch 587 Batch 0 Loss 0.02719125524163246
# Epoch 587 Loss 0.04887126758694649
# Time taken for 1 epoch 0.1258406639099121 sec
#
# Epoch 588 Batch 0 Loss 0.027317965403199196
# Epoch 588 Loss 0.046602193266153336
# Time taken for 1 epoch 0.12973403930664062 sec
#
# Epoch 589 Batch 0 Loss 0.02719241939485073
# Epoch 589 Loss 0.04687381908297539
# Time taken for 1 epoch 0.11421966552734375 sec
#
# Epoch 590 Batch 0 Loss 0.02889244630932808
# Epoch 590 Loss 0.0457160584628582
# Time taken for 1 epoch 0.19224905967712402 sec
#
# Epoch 591 Batch 0 Loss 0.028025859966874123
# Epoch 591 Loss 0.04529346525669098
# Time taken for 1 epoch 0.1234900951385498 sec
#
# Epoch 592 Batch 0 Loss 0.03058808296918869
# Epoch 592 Loss 0.04295654222369194
# Time taken for 1 epoch 0.13419771194458008 sec
#
# Epoch 593 Batch 0 Loss 0.028840312734246254
# Epoch 593 Loss 0.046408578753471375
# Time taken for 1 epoch 0.14130783081054688 sec
#
# Epoch 594 Batch 0 Loss 0.027357425540685654
# Epoch 594 Loss 0.04585263133049011
# Time taken for 1 epoch 0.14290690422058105 sec
#
# Epoch 595 Batch 0 Loss 0.02758488617837429
# Epoch 595 Loss 0.045324429869651794
# Time taken for 1 epoch 0.1577751636505127 sec
#
# Epoch 596 Batch 0 Loss 0.02813335880637169
# Epoch 596 Loss 0.04880346357822418
# Time taken for 1 epoch 0.11883211135864258 sec
#
# Epoch 597 Batch 0 Loss 0.029265394434332848
# Epoch 597 Loss 0.04407629370689392
# Time taken for 1 epoch 0.13152289390563965 sec
#
# Epoch 598 Batch 0 Loss 0.02716320939362049
# Epoch 598 Loss 0.05258407071232796
# Time taken for 1 epoch 0.11413860321044922 sec
#
# Epoch 599 Batch 0 Loss 0.02766653150320053
# Epoch 599 Loss 0.04973527416586876
# Time taken for 1 epoch 0.10997891426086426 sec
#
# Epoch 600 Batch 0 Loss 0.028059618547558784
# Epoch 600 Loss 0.0469076968729496
# Time taken for 1 epoch 0.14133358001708984 sec
#
# Epoch 601 Batch 0 Loss 0.02651026099920273
# Epoch 601 Loss 0.043361205607652664
# Time taken for 1 epoch 0.11318445205688477 sec
#
# Epoch 602 Batch 0 Loss 0.02975870668888092
# Epoch 602 Loss 0.046627338975667953
# Time taken for 1 epoch 0.11766409873962402 sec
#
# Epoch 603 Batch 0 Loss 0.02902192808687687
# Epoch 603 Loss 0.04449784383177757
# Time taken for 1 epoch 0.12209630012512207 sec
#
# Epoch 604 Batch 0 Loss 0.029503608122467995
# Epoch 604 Loss 0.05378533527255058
# Time taken for 1 epoch 0.133286714553833 sec
#
# Epoch 605 Batch 0 Loss 0.02965625375509262
# Epoch 605 Loss 0.04390033707022667
# Time taken for 1 epoch 0.14833569526672363 sec
#
# Epoch 606 Batch 0 Loss 0.027746083214879036
# Epoch 606 Loss 0.05124368146061897
# Time taken for 1 epoch 0.11608767509460449 sec
#
# Epoch 607 Batch 0 Loss 0.03003212995827198
# Epoch 607 Loss 0.04598178341984749
# Time taken for 1 epoch 0.10591483116149902 sec
#
# Epoch 608 Batch 0 Loss 0.029666366055607796
# Epoch 608 Loss 0.04965290427207947
# Time taken for 1 epoch 0.1082761287689209 sec
#
# Epoch 609 Batch 0 Loss 0.02724992111325264
# Epoch 609 Loss 0.05183359980583191
# Time taken for 1 epoch 0.10504603385925293 sec
#
# Epoch 610 Batch 0 Loss 0.028481850400567055
# Epoch 610 Loss 0.047648925334215164
# Time taken for 1 epoch 0.1393578052520752 sec
#
# Epoch 611 Batch 0 Loss 0.028553135693073273
# Epoch 611 Loss 0.047078222036361694
# Time taken for 1 epoch 0.10742926597595215 sec
#
# Epoch 612 Batch 0 Loss 0.029648838564753532
# Epoch 612 Loss 0.04365142807364464
# Time taken for 1 epoch 0.11336517333984375 sec
#
# Epoch 613 Batch 0 Loss 0.02994294837117195
# Epoch 613 Loss 0.04490165412425995
# Time taken for 1 epoch 0.11129498481750488 sec
#
# Epoch 614 Batch 0 Loss 0.027500398457050323
# Epoch 614 Loss 0.04603765904903412
# Time taken for 1 epoch 0.11172771453857422 sec
#
# Epoch 615 Batch 0 Loss 0.02884647436439991
# Epoch 615 Loss 0.050451017916202545
# Time taken for 1 epoch 0.1365833282470703 sec
#
# Epoch 616 Batch 0 Loss 0.029201658442616463
# Epoch 616 Loss 0.04258576035499573
# Time taken for 1 epoch 0.11332106590270996 sec
#
# Epoch 617 Batch 0 Loss 0.028618035838007927
# Epoch 617 Loss 0.043948717415332794
# Time taken for 1 epoch 0.1025543212890625 sec
#
# Epoch 618 Batch 0 Loss 0.026266900822520256
# Epoch 618 Loss 0.04677225649356842
# Time taken for 1 epoch 0.10766410827636719 sec
#
# Epoch 619 Batch 0 Loss 0.025752563029527664
# Epoch 619 Loss 0.04784255474805832
# Time taken for 1 epoch 0.11498570442199707 sec
#
# Epoch 620 Batch 0 Loss 0.029115311801433563
# Epoch 620 Loss 0.049151405692100525
# Time taken for 1 epoch 0.1315319538116455 sec
#
# Epoch 621 Batch 0 Loss 0.029378289356827736
# Epoch 621 Loss 0.04707324877381325
# Time taken for 1 epoch 0.10731267929077148 sec
#
# Epoch 622 Batch 0 Loss 0.027699030935764313
# Epoch 622 Loss 0.04535824805498123
# Time taken for 1 epoch 0.10670757293701172 sec
#
# Epoch 623 Batch 0 Loss 0.02827565371990204
# Epoch 623 Loss 0.04596080631017685
# Time taken for 1 epoch 0.10863304138183594 sec
#
# Epoch 624 Batch 0 Loss 0.029558053240180016
# Epoch 624 Loss 0.0423165038228035
# Time taken for 1 epoch 0.10802674293518066 sec
#
# Epoch 625 Batch 0 Loss 0.028600122779607773
# Epoch 625 Loss 0.04301975294947624
# Time taken for 1 epoch 0.18782711029052734 sec
#
# Epoch 626 Batch 0 Loss 0.029826726764440536
# Epoch 626 Loss 0.04919419437646866
# Time taken for 1 epoch 0.13564825057983398 sec
#
# Epoch 627 Batch 0 Loss 0.028264256194233894
# Epoch 627 Loss 0.0453328974545002
# Time taken for 1 epoch 0.10843682289123535 sec
#
# Epoch 628 Batch 0 Loss 0.028490694239735603
# Epoch 628 Loss 0.044172730296850204
# Time taken for 1 epoch 0.1052846908569336 sec
#
# Epoch 629 Batch 0 Loss 0.02903851494193077
# Epoch 629 Loss 0.046094417572021484
# Time taken for 1 epoch 0.1089015007019043 sec
#
# Epoch 630 Batch 0 Loss 0.028012508526444435
# Epoch 630 Loss 0.04053543880581856
# ...
# Time taken for 1 epoch 0.12155628204345703 sec
#
# Epoch 1377 Batch 0 Loss 0.02719999849796295
# Epoch 1377 Loss 0.03753900155425072
# Time taken for 1 epoch 0.11121582984924316 sec
#
# Epoch 1378 Batch 0 Loss 0.026660213246941566
# Epoch 1378 Loss 0.04016394540667534
# Time taken for 1 epoch 0.11127519607543945 sec
#
# Epoch 1379 Batch 0 Loss 0.02509274333715439
# Epoch 1379 Loss 0.03999301791191101
# Time taken for 1 epoch 0.11934161186218262 sec
#
# Epoch 1380 Batch 0 Loss 0.026500573381781578
# Epoch 1380 Loss 0.04193653538823128
# Time taken for 1 epoch 0.13486027717590332 sec
#
# Epoch 1381 Batch 0 Loss 0.025884166359901428
# Epoch 1381 Loss 0.03822319954633713
# Time taken for 1 epoch 0.12336611747741699 sec
#
# Epoch 1382 Batch 0 Loss 0.02457931451499462
# Epoch 1382 Loss 0.03595316782593727
# Time taken for 1 epoch 0.12044048309326172 sec
#
# Epoch 1383 Batch 0 Loss 0.027809280902147293
# Epoch 1383 Loss 0.036314304918050766
# Time taken for 1 epoch 0.12270855903625488 sec
#
# Epoch 1384 Batch 0 Loss 0.026471368968486786
# Epoch 1384 Loss 0.0383404940366745
# Time taken for 1 epoch 0.10915708541870117 sec
#
# Epoch 1385 Batch 0 Loss 0.02691931277513504
# Epoch 1385 Loss 0.0438799224793911
# Time taken for 1 epoch 0.14064455032348633 sec
#
# Epoch 1386 Batch 0 Loss 0.025854920968413353
# Epoch 1386 Loss 0.04271824657917023
# Time taken for 1 epoch 0.10806536674499512 sec
#
# Epoch 1387 Batch 0 Loss 0.024941461160779
# Epoch 1387 Loss 0.041208017617464066
# Time taken for 1 epoch 0.11548542976379395 sec
#
# Epoch 1388 Batch 0 Loss 0.0258808471262455
# Epoch 1388 Loss 0.036760032176971436
# Time taken for 1 epoch 0.10947155952453613 sec
#
# Epoch 1389 Batch 0 Loss 0.02586592361330986
# Epoch 1389 Loss 0.041258443146944046
# Time taken for 1 epoch 0.10765314102172852 sec
#
# Epoch 1390 Batch 0 Loss 0.02710842527449131
# Epoch 1390 Loss 0.038269925862550735
# Time taken for 1 epoch 0.13482022285461426 sec
#
# Epoch 1391 Batch 0 Loss 0.027028877288103104
# Epoch 1391 Loss 0.03955911844968796
# Time taken for 1 epoch 0.1104428768157959 sec
#
# Epoch 1392 Batch 0 Loss 0.02492775022983551
# Epoch 1392 Loss 0.041802968829870224
# Time taken for 1 epoch 0.10725975036621094 sec
#
# Epoch 1393 Batch 0 Loss 0.025082750245928764
# Epoch 1393 Loss 0.03956477344036102
# Time taken for 1 epoch 0.10491490364074707 sec
#
# Epoch 1394 Batch 0 Loss 0.02637813612818718
# Epoch 1394 Loss 0.04148464277386665
# Time taken for 1 epoch 0.10637116432189941 sec
#
# Epoch 1395 Batch 0 Loss 0.026693083345890045
# Epoch 1395 Loss 0.03562883660197258
# Time taken for 1 epoch 0.15314483642578125 sec
#
# Epoch 1396 Batch 0 Loss 0.024041829630732536
# Epoch 1396 Loss 0.039002675563097
# Time taken for 1 epoch 0.12428712844848633 sec
#
# Epoch 1397 Batch 0 Loss 0.026018567383289337
# Epoch 1397 Loss 0.042936038225889206
# Time taken for 1 epoch 0.11019492149353027 sec
#
# Epoch 1398 Batch 0 Loss 0.0265857744961977
# Epoch 1398 Loss 0.041252851486206055
# Time taken for 1 epoch 0.12538838386535645 sec
#
# Epoch 1399 Batch 0 Loss 0.027176279574632645
# Epoch 1399 Loss 0.041559237986803055
# Time taken for 1 epoch 0.12121415138244629 sec
#
# Epoch 1400 Batch 0 Loss 0.026072775945067406
# Epoch 1400 Loss 0.035055533051490784
# Time taken for 1 epoch 0.14787673950195312 sec
#
# Epoch 1401 Batch 0 Loss 0.024701248854398727
# Epoch 1401 Loss 0.03529675304889679
# Time taken for 1 epoch 0.10427594184875488 sec
#
# Epoch 1402 Batch 0 Loss 0.024366719648241997
# Epoch 1402 Loss 0.039564505219459534
# Time taken for 1 epoch 0.1184988021850586 sec
#
# Epoch 1403 Batch 0 Loss 0.026673128828406334
# Epoch 1403 Loss 0.03711347654461861
# Time taken for 1 epoch 0.11860251426696777 sec
#
# Epoch 1404 Batch 0 Loss 0.026926957070827484
# Epoch 1404 Loss 0.035996511578559875
# Time taken for 1 epoch 0.1202399730682373 sec
#
# Epoch 1405 Batch 0 Loss 0.027123942971229553
# Epoch 1405 Loss 0.03778921440243721
# Time taken for 1 epoch 0.15115928649902344 sec
#
# Epoch 1406 Batch 0 Loss 0.025873662903904915
# Epoch 1406 Loss 0.03853948041796684
# Time taken for 1 epoch 0.12291550636291504 sec
#
# Epoch 1407 Batch 0 Loss 0.026662049815058708
# Epoch 1407 Loss 0.03756887838244438
# Time taken for 1 epoch 0.1253197193145752 sec
#
# Epoch 1408 Batch 0 Loss 0.026860656216740608
# Epoch 1408 Loss 0.038813281804323196
# Time taken for 1 epoch 0.12436270713806152 sec
#
# Epoch 1409 Batch 0 Loss 0.02441098913550377
# Epoch 1409 Loss 0.04065965488553047
# Time taken for 1 epoch 0.11921262741088867 sec
#
# Epoch 1410 Batch 0 Loss 0.02455749548971653
# Epoch 1410 Loss 0.0409286729991436
# Time taken for 1 epoch 0.18176937103271484 sec
#
# Epoch 1411 Batch 0 Loss 0.026199568063020706
# Epoch 1411 Loss 0.03669360280036926
# Time taken for 1 epoch 0.14807772636413574 sec
#
# Epoch 1412 Batch 0 Loss 0.02672496996819973
# Epoch 1412 Loss 0.03613695502281189
# Time taken for 1 epoch 0.10282254219055176 sec
#
# Epoch 1413 Batch 0 Loss 0.024385904893279076
# Epoch 1413 Loss 0.04080846905708313
# Time taken for 1 epoch 0.10524439811706543 sec
#
# Epoch 1414 Batch 0 Loss 0.02516246773302555
# Epoch 1414 Loss 0.03716469183564186
# Time taken for 1 epoch 0.10656881332397461 sec
#
# Epoch 1415 Batch 0 Loss 0.02645481377840042
# Epoch 1415 Loss 0.032633744180202484
# Time taken for 1 epoch 0.1526508331298828 sec
#
# Epoch 1416 Batch 0 Loss 0.02631969377398491
# Epoch 1416 Loss 0.04102746397256851
# Time taken for 1 epoch 0.10837507247924805 sec
#
# Epoch 1417 Batch 0 Loss 0.02598859742283821
# Epoch 1417 Loss 0.04004223644733429
# Time taken for 1 epoch 0.10727739334106445 sec
#
# Epoch 1418 Batch 0 Loss 0.027237003669142723
# Epoch 1418 Loss 0.0402500182390213
# Time taken for 1 epoch 0.10704660415649414 sec
#
# Epoch 1419 Batch 0 Loss 0.02686476707458496
# Epoch 1419 Loss 0.03992225602269173
# Time taken for 1 epoch 0.10966205596923828 sec
#
# Epoch 1420 Batch 0 Loss 0.027036966755986214
# Epoch 1420 Loss 0.034268733114004135
# Time taken for 1 epoch 0.14812517166137695 sec
#
# Epoch 1421 Batch 0 Loss 0.025494180619716644
# Epoch 1421 Loss 0.03944939002394676
# Time taken for 1 epoch 0.11158084869384766 sec
#
# Epoch 1422 Batch 0 Loss 0.026581821963191032
# Epoch 1422 Loss 0.036010898649692535
# Time taken for 1 epoch 0.12089085578918457 sec
#
# Epoch 1423 Batch 0 Loss 0.027360152453184128
# Epoch 1423 Loss 0.03812328726053238
# Time taken for 1 epoch 0.11676359176635742 sec
#
# Epoch 1424 Batch 0 Loss 0.026165831834077835
# Epoch 1424 Loss 0.04091798886656761
# Time taken for 1 epoch 0.1247563362121582 sec
#
# Epoch 1425 Batch 0 Loss 0.02727610431611538
# Epoch 1425 Loss 0.038858771324157715
# Time taken for 1 epoch 0.14703726768493652 sec
#
# Epoch 1426 Batch 0 Loss 0.027856998145580292
# Epoch 1426 Loss 0.038007140159606934
# Time taken for 1 epoch 0.11361217498779297 sec
#
# Epoch 1427 Batch 0 Loss 0.025450849905610085
# Epoch 1427 Loss 0.036512039601802826
# Time taken for 1 epoch 0.1164102554321289 sec
#
# Epoch 1428 Batch 0 Loss 0.025996139273047447
# Epoch 1428 Loss 0.035628244280815125
# Time taken for 1 epoch 0.12350797653198242 sec
#
# Epoch 1429 Batch 0 Loss 0.02616192400455475
# Epoch 1429 Loss 0.03668243810534477
# Time taken for 1 epoch 0.11617255210876465 sec
#
# Epoch 1430 Batch 0 Loss 0.02617868408560753
# Epoch 1430 Loss 0.037288445979356766
# Time taken for 1 epoch 0.1548447608947754 sec
#
# Epoch 1431 Batch 0 Loss 0.02610781602561474
# Epoch 1431 Loss 0.037383388727903366
# Time taken for 1 epoch 0.1144096851348877 sec
#
# Epoch 1432 Batch 0 Loss 0.02678389474749565
# Epoch 1432 Loss 0.04277656599879265
# Time taken for 1 epoch 0.1216576099395752 sec
#
# Epoch 1433 Batch 0 Loss 0.02593831531703472
# Epoch 1433 Loss 0.03816753625869751
# Time taken for 1 epoch 0.10746431350708008 sec
#
# Epoch 1434 Batch 0 Loss 0.025853591039776802
# Epoch 1434 Loss 0.037512000650167465
# Time taken for 1 epoch 0.10400271415710449 sec
#
# Epoch 1435 Batch 0 Loss 0.023902835324406624
# Epoch 1435 Loss 0.03635440021753311
# Time taken for 1 epoch 0.1295771598815918 sec
#
# Epoch 1436 Batch 0 Loss 0.027395106852054596
# Epoch 1436 Loss 0.04204588010907173
# Time taken for 1 epoch 0.11361050605773926 sec
#
# Epoch 1437 Batch 0 Loss 0.024969004094600677
# Epoch 1437 Loss 0.041609153151512146
# Time taken for 1 epoch 0.12008905410766602 sec
#
# Epoch 1438 Batch 0 Loss 0.026603708043694496
# Epoch 1438 Loss 0.03520004451274872
# Time taken for 1 epoch 0.1177971363067627 sec
#
# Epoch 1439 Batch 0 Loss 0.024364393204450607
# Epoch 1439 Loss 0.0405239500105381
# Time taken for 1 epoch 0.11997294425964355 sec
#
# Epoch 1440 Batch 0 Loss 0.025671930983662605
# Epoch 1440 Loss 0.03807051479816437
# Time taken for 1 epoch 0.14554190635681152 sec
#
# Epoch 1441 Batch 0 Loss 0.02575892023742199
# Epoch 1441 Loss 0.03747616335749626
# Time taken for 1 epoch 0.11763620376586914 sec
#
# Epoch 1442 Batch 0 Loss 0.02558727189898491
# Epoch 1442 Loss 0.03574589639902115
# Time taken for 1 epoch 0.12179183959960938 sec
#
# Epoch 1443 Batch 0 Loss 0.02549867145717144
# Epoch 1443 Loss 0.04171295091509819
# Time taken for 1 epoch 0.11895418167114258 sec
#
# Epoch 1444 Batch 0 Loss 0.026875460520386696
# Epoch 1444 Loss 0.0367695577442646
# Time taken for 1 epoch 0.12545347213745117 sec
#
# Epoch 1445 Batch 0 Loss 0.025029873475432396
# Epoch 1445 Loss 0.04143652319908142
# Time taken for 1 epoch 0.15621614456176758 sec
#
# Epoch 1446 Batch 0 Loss 0.025285638868808746
# Epoch 1446 Loss 0.04260166734457016
# Time taken for 1 epoch 0.1192467212677002 sec
#
# Epoch 1447 Batch 0 Loss 0.025242628529667854
# Epoch 1447 Loss 0.03804069384932518
# Time taken for 1 epoch 0.11843299865722656 sec
#
# Epoch 1448 Batch 0 Loss 0.026865970343351364
# Epoch 1448 Loss 0.034061022102832794
# Time taken for 1 epoch 0.12266206741333008 sec
#
# Epoch 1449 Batch 0 Loss 0.026425542309880257
# Epoch 1449 Loss 0.0320449098944664
# Time taken for 1 epoch 0.1079411506652832 sec
#
# Epoch 1450 Batch 0 Loss 0.02842538431286812
# Epoch 1450 Loss 0.042444974184036255
# Time taken for 1 epoch 0.1411912441253662 sec
#
# Epoch 1451 Batch 0 Loss 0.024835551157593727
# Epoch 1451 Loss 0.035878878086805344
# Time taken for 1 epoch 0.11626791954040527 sec
#
# Epoch 1452 Batch 0 Loss 0.027590904384851456
# Epoch 1452 Loss 0.04012316092848778
# Time taken for 1 epoch 0.10738396644592285 sec
#
# Epoch 1453 Batch 0 Loss 0.027982471510767937
# Epoch 1453 Loss 0.035094376653432846
# Time taken for 1 epoch 0.10481929779052734 sec
#
# Epoch 1454 Batch 0 Loss 0.02539706788957119
# Epoch 1454 Loss 0.03512777388095856
# Time taken for 1 epoch 0.10355138778686523 sec
#
# Epoch 1455 Batch 0 Loss 0.025773590430617332
# Epoch 1455 Loss 0.03667965903878212
# Time taken for 1 epoch 0.17041611671447754 sec
#
# Epoch 1456 Batch 0 Loss 0.025031743571162224
# Epoch 1456 Loss 0.03410136327147484
# Time taken for 1 epoch 0.1754617691040039 sec
#
# Epoch 1457 Batch 0 Loss 0.02725110948085785
# Epoch 1457 Loss 0.033914387226104736
# Time taken for 1 epoch 0.11489248275756836 sec
#
# Epoch 1458 Batch 0 Loss 0.025945816189050674
# Epoch 1458 Loss 0.03775126487016678
# Time taken for 1 epoch 0.11604928970336914 sec
#
# Epoch 1459 Batch 0 Loss 0.02735225111246109
# Epoch 1459 Loss 0.033521298319101334
# Time taken for 1 epoch 0.1014552116394043 sec
#
# Epoch 1460 Batch 0 Loss 0.024983149021863937
# Epoch 1460 Loss 0.036685533821582794
# Time taken for 1 epoch 0.151078462600708 sec
#
# Epoch 1461 Batch 0 Loss 0.027808422222733498
# Epoch 1461 Loss 0.03744051605463028
# Time taken for 1 epoch 0.11567282676696777 sec
#
# Epoch 1462 Batch 0 Loss 0.026191644370555878
# Epoch 1462 Loss 0.04070541262626648
# Time taken for 1 epoch 0.10643720626831055 sec
#
# Epoch 1463 Batch 0 Loss 0.02533971332013607
# Epoch 1463 Loss 0.03653274476528168
# Time taken for 1 epoch 0.1067953109741211 sec
#
# Epoch 1464 Batch 0 Loss 0.0269057247787714
# Epoch 1464 Loss 0.03668350726366043
# Time taken for 1 epoch 0.10560798645019531 sec
#
# Epoch 1465 Batch 0 Loss 0.02486679144203663
# Epoch 1465 Loss 0.04016284644603729
# Time taken for 1 epoch 0.17346477508544922 sec
#
# Epoch 1466 Batch 0 Loss 0.025492975488305092
# Epoch 1466 Loss 0.04054686427116394
# Time taken for 1 epoch 0.11496210098266602 sec
#
# Epoch 1467 Batch 0 Loss 0.02640356868505478
# Epoch 1467 Loss 0.03413843736052513
# Time taken for 1 epoch 0.11305069923400879 sec
#
# Epoch 1468 Batch 0 Loss 0.026263050734996796
# Epoch 1468 Loss 0.04073444381356239
# Time taken for 1 epoch 0.10934996604919434 sec
#
# Epoch 1469 Batch 0 Loss 0.024622267112135887
# Epoch 1469 Loss 0.04227824509143829
# Time taken for 1 epoch 0.11675715446472168 sec
#
# Epoch 1470 Batch 0 Loss 0.02732439525425434
# Epoch 1470 Loss 0.03947877883911133
# Time taken for 1 epoch 0.15460729598999023 sec
#
# Epoch 1471 Batch 0 Loss 0.027201611548662186
# Epoch 1471 Loss 0.03767647594213486
# Time taken for 1 epoch 0.11069798469543457 sec
#
# Epoch 1472 Batch 0 Loss 0.02586422860622406
# Epoch 1472 Loss 0.035711582750082016
# Time taken for 1 epoch 0.11381912231445312 sec
#
# Epoch 1473 Batch 0 Loss 0.026198411360383034
# Epoch 1473 Loss 0.036289408802986145
# Time taken for 1 epoch 0.11705994606018066 sec
#
# Epoch 1474 Batch 0 Loss 0.027170537039637566
# Epoch 1474 Loss 0.03773828595876694
# Time taken for 1 epoch 0.11379456520080566 sec
#
# Epoch 1475 Batch 0 Loss 0.025837339460849762
# Epoch 1475 Loss 0.03427550196647644
# Time taken for 1 epoch 0.13965821266174316 sec
#
# Epoch 1476 Batch 0 Loss 0.023607458919286728
# Epoch 1476 Loss 0.03871958702802658
# Time taken for 1 epoch 0.12726259231567383 sec
#
# Epoch 1477 Batch 0 Loss 0.026471741497516632
# Epoch 1477 Loss 0.03658444806933403
# Time taken for 1 epoch 0.12074851989746094 sec
#
# Epoch 1478 Batch 0 Loss 0.024948270991444588
# Epoch 1478 Loss 0.03147827461361885
# Time taken for 1 epoch 0.13388729095458984 sec
#
# Epoch 1479 Batch 0 Loss 0.02671807073056698
# Epoch 1479 Loss 0.03994782269001007
# Time taken for 1 epoch 0.11752915382385254 sec
#
# Epoch 1480 Batch 0 Loss 0.02662360481917858
# Epoch 1480 Loss 0.034384578466415405
# Time taken for 1 epoch 0.15441250801086426 sec
#
# Epoch 1481 Batch 0 Loss 0.024132955819368362
# Epoch 1481 Loss 0.03533967584371567
# Time taken for 1 epoch 0.11260080337524414 sec
#
# Epoch 1482 Batch 0 Loss 0.026452288031578064
# Epoch 1482 Loss 0.037459272891283035
# Time taken for 1 epoch 0.11507534980773926 sec
#
# Epoch 1483 Batch 0 Loss 0.024539010599255562
# Epoch 1483 Loss 0.03830716758966446
# Time taken for 1 epoch 0.10355043411254883 sec
#
# Epoch 1484 Batch 0 Loss 0.026310691609978676
# Epoch 1484 Loss 0.036036573350429535
# Time taken for 1 epoch 0.12743520736694336 sec
#
# Epoch 1485 Batch 0 Loss 0.02495604008436203
# Epoch 1485 Loss 0.03564756363630295
# Time taken for 1 epoch 0.14203596115112305 sec
#
# Epoch 1486 Batch 0 Loss 0.02597677893936634
# Epoch 1486 Loss 0.03287060558795929
# Time taken for 1 epoch 0.1273202896118164 sec
#
# Epoch 1487 Batch 0 Loss 0.02520916983485222
# Epoch 1487 Loss 0.04153088480234146
# Time taken for 1 epoch 0.11394023895263672 sec
#
# Epoch 1488 Batch 0 Loss 0.028371445834636688
# Epoch 1488 Loss 0.03599308803677559
# Time taken for 1 epoch 0.11976480484008789 sec
#
# Epoch 1489 Batch 0 Loss 0.024964692071080208
# Epoch 1489 Loss 0.040035780519247055
# Time taken for 1 epoch 0.11445832252502441 sec
#
# Epoch 1490 Batch 0 Loss 0.025426415726542473
# Epoch 1490 Loss 0.037739019840955734
# Time taken for 1 epoch 0.13670659065246582 sec
#
# Epoch 1491 Batch 0 Loss 0.026339098811149597
# Epoch 1491 Loss 0.03378593549132347
# Time taken for 1 epoch 0.10968232154846191 sec
#
# Epoch 1492 Batch 0 Loss 0.02582670748233795
# Epoch 1492 Loss 0.031396105885505676
# Time taken for 1 epoch 0.11375594139099121 sec
#
# Epoch 1493 Batch 0 Loss 0.024634012952446938
# Epoch 1493 Loss 0.04155172407627106
# Time taken for 1 epoch 0.11102533340454102 sec
#
# Epoch 1494 Batch 0 Loss 0.02730952762067318
# Epoch 1494 Loss 0.03976324200630188
# Time taken for 1 epoch 0.1052243709564209 sec
#
# Epoch 1495 Batch 0 Loss 0.02729504555463791
# Epoch 1495 Loss 0.03938370943069458
# Time taken for 1 epoch 0.13361740112304688 sec
#
# Epoch 1496 Batch 0 Loss 0.027949463576078415
# Epoch 1496 Loss 0.03787060081958771
# Time taken for 1 epoch 0.11607599258422852 sec
#
# Epoch 1497 Batch 0 Loss 0.026741456240415573
# Epoch 1497 Loss 0.03405759111046791
# Time taken for 1 epoch 0.10253024101257324 sec
#
# Epoch 1498 Batch 0 Loss 0.02791067771613598
# Epoch 1498 Loss 0.03587230667471886
# Time taken for 1 epoch 0.10782289505004883 sec
#
# Epoch 1499 Batch 0 Loss 0.023809654638171196
# Epoch 1499 Loss 0.043411027640104294
# Time taken for 1 epoch 0.10625648498535156 sec
#
# Epoch 1500 Batch 0 Loss 0.026088325306773186
# Epoch 1500 Loss 0.03973008692264557
# Time taken for 1 epoch 0.16138148307800293 sec

# %%
add = temtxt.split(r"/").repleace(".txt", " Says: ")
print(add + ecolist generate_text(model, start_string=u"life "))
# Out:
# life rarke in Drug use remains widespread and, crucially, the social costs and personal harms are still large. Prork. Worse, exposing people who use drugs to the criminal world and prisons because of drug use, or nefits are important, they are difficult to measure, they may be realised in different timeframes to the world to take a health-focused approach to reduce the harm from the problematic use of drugs. The use and possession of all illicit drugs but to keep their supply illegal average rent is over a quarter of gross income of an average family.
# Renting has not traditionally National and Labour policies – reducing supply. is uncertain.
# The fundamentals still suck
# Whatever the noise in the housing market, the problem ise in health spending needs to happen now, regardless of other policy.
# Conservatively, we estimate t outcomes for people who avoid convictions, and better life outcomes for their children. These are he US suggests that, while recreational use rises after legalisatio
