# %% [markdown]
# <a href="https://colab.research.google.com/github/eniktab/MoE_nlp/blob/master/AnEconomistPlease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.

# %%
import tensorflow as tf
import numpy as np
import os
import time
trained_model_path = ["https://storage.googleapis.com/bucket-1-free/%20philip/ArthurGrimes.txt", 
                    "https://storage.googleapis.com/bucket-1-free/%20philip/ShamubeelEaqubs.txt"]
# !rm -r /content/training_checkpoints
for i in trained_model_path:
        tf.keras.utils.get_file(
            i.split("/")[-1], i, cache_subdir=os.path.abspath("/content"))
        
# Read, then decode for py2 compat.
text = open('/content/ArthurGrimes.txt', 'rb').read().decode(encoding='utf-8')
print('Length of text: {} characters'.format(len(text)))
# The unique characters in the file
vocab = sorted(set(text))
char2idx = {u:i for i, u in enumerate(vocab)}
idx2char = np.array(vocab)
text_as_int = np.array([char2idx[c] for c in text])
# The maximum length sentence you want for a single input in characters
seq_length = 100
examples_per_epoch = len(text)//(seq_length+1)
# Create training examples / targets
char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)
sequences = char_dataset.batch(seq_length+1, drop_remainder=True)
def split_input_target(chunk):
    input_text = chunk[:-1]
    target_text = chunk[1:]
    return input_text, target_text
dataset = sequences.map(split_input_target)
# Batch size
BATCH_SIZE = 64
BUFFER_SIZE = 10000
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
vocab_size = len(vocab)
embedding_dim = 256
rnn_units = 1024
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim,
                                  batch_input_shape=[batch_size, None]),
        tf.keras.layers.GRU(rnn_units,
                            return_sequences=True,
                            stateful=True,
                            recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size)
    ])
    return model
model = build_model(
    vocab_size=len(vocab),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
    batch_size=BATCH_SIZE)
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
model.compile(optimizer='adam', loss=loss)
# Directory where the checkpoints will be saved
checkpoint_dir = './training_checkpoints/ArthurGrimes'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True
    )

model = build_model(
    vocab_size=len(vocab),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
    batch_size=BATCH_SIZE)

optimizer = tf.keras.optimizers.Adam()

@tf.function
def train_step(inp, target):
    with tf.GradientTape() as tape:
        predictions = model(inp)
        loss = tf.reduce_mean(
            tf.keras.losses.sparse_categorical_crossentropy(
                target, predictions, from_logits=True))
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

    return loss

def generate_text(model, start_string):
    # Evaluation step (generating text using the learned model)

    # Number of characters to generate
    num_generate = 1000

    # Converting our start string to numbers (vectorizing)
    input_eval = [char2idx[s] for s in start_string]
    input_eval = tf.expand_dims(input_eval, 0)

    # Empty string to store our results
    text_generated = []

    # Low temperature results in more predictable text.
    # Higher temperature results in more surprising text.
    # Experiment to find the best setting.
    temperature = 0.5

    model.reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)
        # remove the batch dimension
        predictions = tf.squeeze(predictions, 0)

        # using a categorical distribution to predict the character returned by the model
        predictions = predictions / temperature
        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

        # Pass the predicted character as the next input to the model
        # along with the previous hidden state
        input_eval = tf.expand_dims([predicted_id], 0)

        text_generated.append(idx2char[predicted_id])

    return (start_string + ''.join(text_generated))
  
tf.train.latest_checkpoint(checkpoint_dir)
# Training step
EPOCHS = 500

for epoch in range(EPOCHS):
    start = time.time()

    # resetting the hidden state at the start of every epoch
    model.reset_states()

    for (batch_n, (inp, target)) in enumerate(dataset):
        loss = train_step(inp, target)

        if batch_n % 100 == 0:
            template = 'Epoch {} Batch {} Loss {}'
            print(template.format(epoch + 1, batch_n, loss))

    # saving (checkpoint) the model every 5 epochs
    if (epoch + 1) % 5 == 0:
        model.save_weights(checkpoint_prefix.format(epoch=epoch))

    print('Epoch {} Loss {:}'.format(epoch + 1, loss))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))

model.save_weights(checkpoint_prefix.format(epoch=epoch))

tf.train.latest_checkpoint(checkpoint_dir)
model = build_model(vocab_size, embedding_dim, rnn_units, batch_size=1)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, None]))

print(generate_text(model, start_string=u"life "))
# Out:
# Length of text: 22003 characters
# Epoch 1 Batch 0 Loss 4.430296421051025
# Epoch 1 Loss 4.312024116516113
# Time taken for 1 epoch 1.319605827331543 sec
#
# Epoch 2 Batch 0 Loss 4.019466400146484
# Epoch 2 Loss 3.738147020339966
# Time taken for 1 epoch 0.11127686500549316 sec
#
# Epoch 3 Batch 0 Loss 3.8674395084381104
# Epoch 3 Loss 4.012645244598389
# Time taken for 1 epoch 0.11093926429748535 sec
#
# Epoch 4 Batch 0 Loss 4.005490303039551
# Epoch 4 Loss 3.8831470012664795
# Time taken for 1 epoch 0.11320996284484863 sec
#
# Epoch 5 Batch 0 Loss 3.8023910522460938
# Epoch 5 Loss 3.711963415145874
# Time taken for 1 epoch 0.13892722129821777 sec
#
# Epoch 6 Batch 0 Loss 3.690441370010376
# Epoch 6 Loss 3.5178825855255127
# Time taken for 1 epoch 0.10641050338745117 sec
#
# Epoch 7 Batch 0 Loss 3.4501852989196777
# Epoch 7 Loss 3.306368827819824
# Time taken for 1 epoch 0.11281132698059082 sec
#
# Epoch 8 Batch 0 Loss 3.271874189376831
# Epoch 8 Loss 3.1022698879241943
# Time taken for 1 epoch 0.12494683265686035 sec
#
# Epoch 9 Batch 0 Loss 3.0465173721313477
# Epoch 9 Loss 3.0723156929016113
# Time taken for 1 epoch 0.1218864917755127 sec
#
# Epoch 10 Batch 0 Loss 3.0640180110931396
# Epoch 10 Loss 2.9717211723327637
# Time taken for 1 epoch 0.13780760765075684 sec
#
# Epoch 11 Batch 0 Loss 2.9665093421936035
# Epoch 11 Loss 2.8656516075134277
# Time taken for 1 epoch 0.10947084426879883 sec
#
# Epoch 12 Batch 0 Loss 2.901564359664917
# Epoch 12 Loss 2.8970415592193604
# Time taken for 1 epoch 0.11491823196411133 sec
#
# Epoch 13 Batch 0 Loss 2.858539342880249
# Epoch 13 Loss 2.894033193588257
# Time taken for 1 epoch 0.11353945732116699 sec
#
# Epoch 14 Batch 0 Loss 2.862032413482666
# Epoch 14 Loss 2.7813491821289062
# Time taken for 1 epoch 0.1076347827911377 sec
#
# Epoch 15 Batch 0 Loss 2.7480504512786865
# Epoch 15 Loss 2.789644479751587
# Time taken for 1 epoch 0.13794279098510742 sec
#
# Epoch 16 Batch 0 Loss 2.7171642780303955
# Epoch 16 Loss 2.672220468521118
# Time taken for 1 epoch 0.10456490516662598 sec
#
# Epoch 17 Batch 0 Loss 2.7096199989318848
# Epoch 17 Loss 2.6046664714813232
# Time taken for 1 epoch 0.10540890693664551 sec
#
# Epoch 18 Batch 0 Loss 2.652524471282959
# Epoch 18 Loss 2.626826524734497
# Time taken for 1 epoch 0.11255764961242676 sec
#
# Epoch 19 Batch 0 Loss 2.572488307952881
# Epoch 19 Loss 2.5608792304992676
# Time taken for 1 epoch 0.10840773582458496 sec
#
# Epoch 20 Batch 0 Loss 2.5189383029937744
# Epoch 20 Loss 2.5573155879974365
# Time taken for 1 epoch 0.1366417407989502 sec
#
# Epoch 21 Batch 0 Loss 2.533831834793091
# Epoch 21 Loss 2.524601459503174
# Time taken for 1 epoch 0.11076831817626953 sec
#
# Epoch 22 Batch 0 Loss 2.527916669845581
# Epoch 22 Loss 2.4388492107391357
# Time taken for 1 epoch 0.1090703010559082 sec
#
# Epoch 23 Batch 0 Loss 2.4428718090057373
# Epoch 23 Loss 2.462491989135742
# Time taken for 1 epoch 0.11063647270202637 sec
#
# Epoch 24 Batch 0 Loss 2.433788299560547
# Epoch 24 Loss 2.424405097961426
# Time taken for 1 epoch 0.10827183723449707 sec
#
# Epoch 25 Batch 0 Loss 2.406651258468628
# Epoch 25 Loss 2.43295955657959
# Time taken for 1 epoch 0.13578343391418457 sec
#
# Epoch 26 Batch 0 Loss 2.395918846130371
# Epoch 26 Loss 2.436734199523926
# Time taken for 1 epoch 0.11326956748962402 sec
#
# Epoch 27 Batch 0 Loss 2.3783295154571533
# Epoch 27 Loss 2.403651714324951
# Time taken for 1 epoch 0.13718676567077637 sec
#
# Epoch 28 Batch 0 Loss 2.4104299545288086
# Epoch 28 Loss 2.3502538204193115
# Time taken for 1 epoch 0.11017274856567383 sec
#
# Epoch 29 Batch 0 Loss 2.3504271507263184
# Epoch 29 Loss 2.3355846405029297
# Time taken for 1 epoch 0.10938358306884766 sec
#
# Epoch 30 Batch 0 Loss 2.299788475036621
# Epoch 30 Loss 2.3590588569641113
# Time taken for 1 epoch 0.13912439346313477 sec
#
# Epoch 31 Batch 0 Loss 2.331265449523926
# Epoch 31 Loss 2.3111815452575684
# Time taken for 1 epoch 0.10893678665161133 sec
#
# Epoch 32 Batch 0 Loss 2.3015124797821045
# Epoch 32 Loss 2.290407419204712
# Time taken for 1 epoch 0.10430908203125 sec
#
# Epoch 33 Batch 0 Loss 2.318723678588867
# Epoch 33 Loss 2.275756597518921
# Time taken for 1 epoch 0.10806751251220703 sec
#
# Epoch 34 Batch 0 Loss 2.2844972610473633
# Epoch 34 Loss 2.251251459121704
# Time taken for 1 epoch 0.12604069709777832 sec
#
# Epoch 35 Batch 0 Loss 2.300222396850586
# Epoch 35 Loss 2.1951987743377686
# Time taken for 1 epoch 0.15784692764282227 sec
#
# Epoch 36 Batch 0 Loss 2.25382661819458
# Epoch 36 Loss 2.2235631942749023
# Time taken for 1 epoch 0.1299889087677002 sec
#
# Epoch 37 Batch 0 Loss 2.2098002433776855
# Epoch 37 Loss 2.2190191745758057
# Time taken for 1 epoch 0.1098480224609375 sec
#
# Epoch 38 Batch 0 Loss 2.2221620082855225
# Epoch 38 Loss 2.16524600982666
# Time taken for 1 epoch 0.10419106483459473 sec
#
# Epoch 39 Batch 0 Loss 2.189532518386841
# Epoch 39 Loss 2.1883819103240967
# Time taken for 1 epoch 0.10833287239074707 sec
#
# Epoch 40 Batch 0 Loss 2.2129878997802734
# Epoch 40 Loss 2.211111545562744
# Time taken for 1 epoch 0.16230297088623047 sec
#
# Epoch 41 Batch 0 Loss 2.168499708175659
# Epoch 41 Loss 2.165644645690918
# Time taken for 1 epoch 0.11396050453186035 sec
#
# Epoch 42 Batch 0 Loss 2.1598148345947266
# Epoch 42 Loss 2.1487228870391846
# Time taken for 1 epoch 0.12058568000793457 sec
#
# Epoch 43 Batch 0 Loss 2.1402978897094727
# Epoch 43 Loss 2.1535537242889404
# Time taken for 1 epoch 0.10706472396850586 sec
#
# Epoch 44 Batch 0 Loss 2.1207480430603027
# Epoch 44 Loss 2.1304736137390137
# Time taken for 1 epoch 0.10461020469665527 sec
#
# Epoch 45 Batch 0 Loss 2.1178879737854004
# Epoch 45 Loss 2.0929808616638184
# Time taken for 1 epoch 0.1370985507965088 sec
#
# Epoch 46 Batch 0 Loss 2.092433452606201
# Epoch 46 Loss 2.0809261798858643
# Time taken for 1 epoch 0.1068577766418457 sec
#
# Epoch 47 Batch 0 Loss 2.0706472396850586
# Epoch 47 Loss 2.0835297107696533
# Time taken for 1 epoch 0.10499191284179688 sec
#
# Epoch 48 Batch 0 Loss 2.0826621055603027
# Epoch 48 Loss 2.0528619289398193
# Time taken for 1 epoch 0.1051480770111084 sec
#
# Epoch 49 Batch 0 Loss 2.0630486011505127
# Epoch 49 Loss 2.0681371688842773
# Time taken for 1 epoch 0.10760021209716797 sec
#
# Epoch 50 Batch 0 Loss 2.0407328605651855
# Epoch 50 Loss 2.009874105453491
# Time taken for 1 epoch 0.13473939895629883 sec
#
# Epoch 51 Batch 0 Loss 2.009371757507324
# Epoch 51 Loss 1.9987186193466187
# Time taken for 1 epoch 0.1084756851196289 sec
#
# Epoch 52 Batch 0 Loss 2.0074570178985596
# Epoch 52 Loss 1.9856082201004028
# Time taken for 1 epoch 0.10703349113464355 sec
#
# Epoch 53 Batch 0 Loss 1.9821363687515259
# Epoch 53 Loss 1.9652096033096313
# Time taken for 1 epoch 0.11301326751708984 sec
#
# Epoch 54 Batch 0 Loss 1.975905179977417
# Epoch 54 Loss 1.9495257139205933
# Time taken for 1 epoch 0.10251855850219727 sec
#
# Epoch 55 Batch 0 Loss 1.9420236349105835
# Epoch 55 Loss 1.9169526100158691
# Time taken for 1 epoch 0.13570404052734375 sec
#
# Epoch 56 Batch 0 Loss 1.9352993965148926
# Epoch 56 Loss 1.926169991493225
# Time taken for 1 epoch 0.10715818405151367 sec
#
# Epoch 57 Batch 0 Loss 1.9125889539718628
# Epoch 57 Loss 1.8930480480194092
# Time taken for 1 epoch 0.10556197166442871 sec
#
# Epoch 58 Batch 0 Loss 1.8514138460159302
# Epoch 58 Loss 1.8901461362838745
# Time taken for 1 epoch 0.10367894172668457 sec
#
# Epoch 59 Batch 0 Loss 1.855545997619629
# Epoch 59 Loss 1.867958664894104
# Time taken for 1 epoch 0.10623526573181152 sec
#
# Epoch 60 Batch 0 Loss 1.8621917963027954
# Epoch 60 Loss 1.8414195775985718
# Time taken for 1 epoch 0.14066028594970703 sec
#
# Epoch 61 Batch 0 Loss 1.8097999095916748
# Epoch 61 Loss 1.8119043111801147
# Time taken for 1 epoch 0.10276365280151367 sec
#
# Epoch 62 Batch 0 Loss 1.8348419666290283
# Epoch 62 Loss 1.7794337272644043
# Time taken for 1 epoch 0.10677981376647949 sec
#
# Epoch 63 Batch 0 Loss 1.7766587734222412
# Epoch 63 Loss 1.7678310871124268
# Time taken for 1 epoch 0.10501909255981445 sec
#
# Epoch 64 Batch 0 Loss 1.7712042331695557
# Epoch 64 Loss 1.7501251697540283
# Time taken for 1 epoch 0.10325264930725098 sec
#
# Epoch 65 Batch 0 Loss 1.7533994913101196
# Epoch 65 Loss 1.6967816352844238
# Time taken for 1 epoch 0.13761186599731445 sec
#
# Epoch 66 Batch 0 Loss 1.7452263832092285
# Epoch 66 Loss 1.6667609214782715
# Time taken for 1 epoch 0.14933037757873535 sec
#
# Epoch 67 Batch 0 Loss 1.6732401847839355
# Epoch 67 Loss 1.6773834228515625
# Time taken for 1 epoch 0.10742759704589844 sec
#
# Epoch 68 Batch 0 Loss 1.6778640747070312
# Epoch 68 Loss 1.6720490455627441
# Time taken for 1 epoch 0.1165916919708252 sec
#
# Epoch 69 Batch 0 Loss 1.6221482753753662
# Epoch 69 Loss 1.6403541564941406
# Time taken for 1 epoch 0.11428356170654297 sec
#
# Epoch 70 Batch 0 Loss 1.6295769214630127
# Epoch 70 Loss 1.5891671180725098
# Time taken for 1 epoch 0.1540994644165039 sec
#
# Epoch 71 Batch 0 Loss 1.601651906967163
# Epoch 71 Loss 1.5986255407333374
# Time taken for 1 epoch 0.12446260452270508 sec
#
# Epoch 72 Batch 0 Loss 1.5320658683776855
# Epoch 72 Loss 1.5659403800964355
# Time taken for 1 epoch 0.11939859390258789 sec
#
# Epoch 73 Batch 0 Loss 1.519809603691101
# Epoch 73 Loss 1.5149577856063843
# Time taken for 1 epoch 0.1216580867767334 sec
#
# Epoch 74 Batch 0 Loss 1.5099899768829346
# Epoch 74 Loss 1.4975286722183228
# Time taken for 1 epoch 0.11622810363769531 sec
#
# Epoch 75 Batch 0 Loss 1.4759135246276855
# Epoch 75 Loss 1.490098237991333
# Time taken for 1 epoch 0.14880967140197754 sec
#
# Epoch 76 Batch 0 Loss 1.4332702159881592
# Epoch 76 Loss 1.4792081117630005
# Time taken for 1 epoch 0.11267685890197754 sec
#
# Epoch 77 Batch 0 Loss 1.4318797588348389
# Epoch 77 Loss 1.4428181648254395
# Time taken for 1 epoch 0.10964798927307129 sec
#
# Epoch 78 Batch 0 Loss 1.3990799188613892
# Epoch 78 Loss 1.3974738121032715
# Time taken for 1 epoch 0.10445404052734375 sec
#
# Epoch 79 Batch 0 Loss 1.4058036804199219
# Epoch 79 Loss 1.3644503355026245
# Time taken for 1 epoch 0.10570764541625977 sec
#
# Epoch 80 Batch 0 Loss 1.3335249423980713
# Epoch 80 Loss 1.3557095527648926
# Time taken for 1 epoch 0.13453102111816406 sec
#
# Epoch 81 Batch 0 Loss 1.3177275657653809
# Epoch 81 Loss 1.3433831930160522
# Time taken for 1 epoch 0.10426712036132812 sec
#
# Epoch 82 Batch 0 Loss 1.2775906324386597
# Epoch 82 Loss 1.2703930139541626
# Time taken for 1 epoch 0.10322356224060059 sec
#
# Epoch 83 Batch 0 Loss 1.2697083950042725
# Epoch 83 Loss 1.2562445402145386
# Time taken for 1 epoch 0.10431623458862305 sec
#
# Epoch 84 Batch 0 Loss 1.2222747802734375
# Epoch 84 Loss 1.2340699434280396
# Time taken for 1 epoch 0.10793924331665039 sec
#
# Epoch 85 Batch 0 Loss 1.2172396183013916
# Epoch 85 Loss 1.1579488515853882
# Time taken for 1 epoch 0.13768792152404785 sec
#
# Epoch 86 Batch 0 Loss 1.1471831798553467
# Epoch 86 Loss 1.1583263874053955
# Time taken for 1 epoch 0.10388422012329102 sec
#
# Epoch 87 Batch 0 Loss 1.1669005155563354
# Epoch 87 Loss 1.135593056678772
# Time taken for 1 epoch 0.1081695556640625 sec
#
# Epoch 88 Batch 0 Loss 1.0981953144073486
# Epoch 88 Loss 1.1130708456039429
# Time taken for 1 epoch 0.10500383377075195 sec
#
# Epoch 89 Batch 0 Loss 1.1161139011383057
# Epoch 89 Loss 1.106460452079773
# Time taken for 1 epoch 0.10790777206420898 sec
#
# Epoch 90 Batch 0 Loss 1.0464482307434082
# Epoch 90 Loss 1.0636157989501953
# Time taken for 1 epoch 0.13720941543579102 sec
#
# Epoch 91 Batch 0 Loss 1.0280654430389404
# Epoch 91 Loss 1.0430108308792114
# Time taken for 1 epoch 0.11594676971435547 sec
#
# Epoch 92 Batch 0 Loss 0.9642845392227173
# Epoch 92 Loss 0.9966539740562439
# Time taken for 1 epoch 0.10955262184143066 sec
#
# Epoch 93 Batch 0 Loss 0.9728456735610962
# Epoch 93 Loss 0.9597797393798828
# Time taken for 1 epoch 0.10783958435058594 sec
#
# Epoch 94 Batch 0 Loss 0.9150373339653015
# Epoch 94 Loss 0.973076343536377
# Time taken for 1 epoch 0.10608792304992676 sec
#
# Epoch 95 Batch 0 Loss 0.8987411260604858
# Epoch 95 Loss 0.9061158895492554
# Time taken for 1 epoch 0.13530397415161133 sec
#
# Epoch 96 Batch 0 Loss 0.8696132898330688
# Epoch 96 Loss 0.8745523691177368
# Time taken for 1 epoch 0.10978484153747559 sec
#
# Epoch 97 Batch 0 Loss 0.8251614570617676
# Epoch 97 Loss 0.8672740459442139
# Time taken for 1 epoch 0.11242938041687012 sec
#
# Epoch 98 Batch 0 Loss 0.810456395149231
# Epoch 98 Loss 0.8155184984207153
# Time taken for 1 epoch 0.11563801765441895 sec
#
# Epoch 99 Batch 0 Loss 0.7606663703918457
# Epoch 99 Loss 0.8020708560943604
# Time taken for 1 epoch 0.11466360092163086 sec
#
# Epoch 100 Batch 0 Loss 0.7514945864677429
# Epoch 100 Loss 0.7865896821022034
# Time taken for 1 epoch 0.15291094779968262 sec
#
# Epoch 101 Batch 0 Loss 0.710757851600647
# Epoch 101 Loss 0.7623945474624634
# Time taken for 1 epoch 0.1580216884613037 sec
#
# Epoch 102 Batch 0 Loss 0.664449155330658
# Epoch 102 Loss 0.7300480604171753
# Time taken for 1 epoch 0.10296916961669922 sec
#
# Epoch 103 Batch 0 Loss 0.6530258059501648
# Epoch 103 Loss 0.6900875568389893
# Time taken for 1 epoch 0.105926513671875 sec
#
# Epoch 104 Batch 0 Loss 0.6310646533966064
# Epoch 104 Loss 0.6558113098144531
# Time taken for 1 epoch 0.11100459098815918 sec
#
# Epoch 105 Batch 0 Loss 0.5901821255683899
# Epoch 105 Loss 0.6312257647514343
# Time taken for 1 epoch 0.15867018699645996 sec
#
# Epoch 106 Batch 0 Loss 0.5593916177749634
# Epoch 106 Loss 0.6320687532424927
# Time taken for 1 epoch 0.1054830551147461 sec
#
# Epoch 107 Batch 0 Loss 0.5391080379486084
# Epoch 107 Loss 0.5808524489402771
# Time taken for 1 epoch 0.10875272750854492 sec
#
# Epoch 108 Batch 0 Loss 0.48917603492736816
# Epoch 108 Loss 0.5734999179840088
# Time taken for 1 epoch 0.10587882995605469 sec
#
# Epoch 109 Batch 0 Loss 0.4894654154777527
# Epoch 109 Loss 0.5356348156929016
# Time taken for 1 epoch 0.10692715644836426 sec
#
# Epoch 110 Batch 0 Loss 0.4604148864746094
# Epoch 110 Loss 0.5183120965957642
# Time taken for 1 epoch 0.14313745498657227 sec
#
# Epoch 111 Batch 0 Loss 0.4420377314090729
# Epoch 111 Loss 0.48740532994270325
# Time taken for 1 epoch 0.12654542922973633 sec
#
# Epoch 112 Batch 0 Loss 0.4080205261707306
# Epoch 112 Loss 0.46158990263938904
# Time taken for 1 epoch 0.11441993713378906 sec
#
# Epoch 113 Batch 0 Loss 0.38637518882751465
# Epoch 113 Loss 0.43832069635391235
# Time taken for 1 epoch 0.11160588264465332 sec
#
# Epoch 114 Batch 0 Loss 0.3643985688686371
# Epoch 114 Loss 0.434321790933609
# Time taken for 1 epoch 0.11984372138977051 sec
#
# Epoch 115 Batch 0 Loss 0.3512525260448456
# Epoch 115 Loss 0.3994359076023102
# Time taken for 1 epoch 0.15050840377807617 sec
#
# Epoch 116 Batch 0 Loss 0.3355751931667328
# Epoch 116 Loss 0.38178330659866333
# Time taken for 1 epoch 0.11350345611572266 sec
#
# Epoch 117 Batch 0 Loss 0.29825541377067566
# Epoch 117 Loss 0.37439262866973877
# Time taken for 1 epoch 0.1103208065032959 sec
#
# Epoch 118 Batch 0 Loss 0.2852012813091278
# Epoch 118 Loss 0.36692237854003906
# Time taken for 1 epoch 0.10866785049438477 sec
#
# Epoch 119 Batch 0 Loss 0.27719125151634216
# Epoch 119 Loss 0.3440508246421814
# Time taken for 1 epoch 0.12094616889953613 sec
#
# Epoch 120 Batch 0 Loss 0.2656775712966919
# Epoch 120 Loss 0.3295225501060486
# Time taken for 1 epoch 0.14992761611938477 sec
#
# Epoch 121 Batch 0 Loss 0.24706095457077026
# Epoch 121 Loss 0.3181070387363434
# Time taken for 1 epoch 0.1145317554473877 sec
#
# Epoch 122 Batch 0 Loss 0.2305184155702591
# Epoch 122 Loss 0.30183669924736023
# Time taken for 1 epoch 0.12293004989624023 sec
#
# Epoch 123 Batch 0 Loss 0.22710686922073364
# Epoch 123 Loss 0.28230077028274536
# Time taken for 1 epoch 0.11146950721740723 sec
#
# Epoch 124 Batch 0 Loss 0.2105758637189865
# Epoch 124 Loss 0.2921087145805359
# Time taken for 1 epoch 0.12148785591125488 sec
#
# Epoch 125 Batch 0 Loss 0.20084960758686066
# Epoch 125 Loss 0.26624760031700134
# Time taken for 1 epoch 0.14000248908996582 sec
#
# Epoch 126 Batch 0 Loss 0.1994551122188568
# Epoch 126 Loss 0.2572633922100067
# Time taken for 1 epoch 0.11056208610534668 sec
#
# Epoch 127 Batch 0 Loss 0.18589985370635986
# Epoch 127 Loss 0.24579128623008728
# Time taken for 1 epoch 0.10711359977722168 sec
#
# Epoch 128 Batch 0 Loss 0.17649997770786285
# Epoch 128 Loss 0.2448379099369049
# Time taken for 1 epoch 0.12580156326293945 sec
#
# Epoch 129 Batch 0 Loss 0.1760322004556656
# Epoch 129 Loss 0.24686774611473083
# Time taken for 1 epoch 0.1196298599243164 sec
#
# Epoch 130 Batch 0 Loss 0.16794711351394653
# Epoch 130 Loss 0.2345610111951828
# Time taken for 1 epoch 0.1509873867034912 sec
#
# Epoch 131 Batch 0 Loss 0.1564866602420807
# Epoch 131 Loss 0.229827418923378
# Time taken for 1 epoch 0.11511063575744629 sec
#
# Epoch 132 Batch 0 Loss 0.151778906583786
# Epoch 132 Loss 0.23662954568862915
# Time taken for 1 epoch 0.12148213386535645 sec
#
# Epoch 133 Batch 0 Loss 0.15054884552955627
# Epoch 133 Loss 0.23134036362171173
# Time taken for 1 epoch 0.11354470252990723 sec
#
# Epoch 134 Batch 0 Loss 0.14592738449573517
# Epoch 134 Loss 0.21941478550434113
# Time taken for 1 epoch 0.12108874320983887 sec
#
# Epoch 135 Batch 0 Loss 0.1333988606929779
# Epoch 135 Loss 0.20537719130516052
# Time taken for 1 epoch 0.1350865364074707 sec
#
# Epoch 136 Batch 0 Loss 0.13280679285526276
# Epoch 136 Loss 0.21298080682754517
# Time taken for 1 epoch 0.11738872528076172 sec
#
# Epoch 137 Batch 0 Loss 0.12716983258724213
# Epoch 137 Loss 0.21143683791160583
# Time taken for 1 epoch 0.10224199295043945 sec
#
# Epoch 138 Batch 0 Loss 0.12376385927200317
# Epoch 138 Loss 0.2182876467704773
# Time taken for 1 epoch 0.10198354721069336 sec
#
# Epoch 139 Batch 0 Loss 0.12281105667352676
# Epoch 139 Loss 0.2019340842962265
# Time taken for 1 epoch 0.10776591300964355 sec
#
# Epoch 140 Batch 0 Loss 0.11931883543729782
# Epoch 140 Loss 0.18798111379146576
# Time taken for 1 epoch 0.15388989448547363 sec
#
# Epoch 141 Batch 0 Loss 0.11944788694381714
# Epoch 141 Loss 0.19550853967666626
# Time taken for 1 epoch 0.13646912574768066 sec
#
# Epoch 142 Batch 0 Loss 0.11184993386268616
# Epoch 142 Loss 0.18298733234405518
# Time taken for 1 epoch 0.1033632755279541 sec
#
# Epoch 143 Batch 0 Loss 0.11283187568187714
# Epoch 143 Loss 0.18884918093681335
# Time taken for 1 epoch 0.11496543884277344 sec
#
# Epoch 144 Batch 0 Loss 0.11110403388738632
# Epoch 144 Loss 0.18670907616615295
# Time taken for 1 epoch 0.12308549880981445 sec
#
# Epoch 145 Batch 0 Loss 0.10955865681171417
# Epoch 145 Loss 0.17450684309005737
# Time taken for 1 epoch 0.16392016410827637 sec
#
# Epoch 146 Batch 0 Loss 0.10807232558727264
# Epoch 146 Loss 0.18356868624687195
# Time taken for 1 epoch 0.1150960922241211 sec
#
# Epoch 147 Batch 0 Loss 0.10046199709177017
# Epoch 147 Loss 0.1840304732322693
# Time taken for 1 epoch 0.1185157299041748 sec
#
# Epoch 148 Batch 0 Loss 0.09856194257736206
# Epoch 148 Loss 0.1711772382259369
# Time taken for 1 epoch 0.11014032363891602 sec
#
# Epoch 149 Batch 0 Loss 0.09998204559087753
# Epoch 149 Loss 0.15999528765678406
# Time taken for 1 epoch 0.10836625099182129 sec
#
# Epoch 150 Batch 0 Loss 0.09163431078195572
# Epoch 150 Loss 0.17846834659576416
# Time taken for 1 epoch 0.1670842170715332 sec
#
# Epoch 151 Batch 0 Loss 0.09403696656227112
# Epoch 151 Loss 0.16674567759037018
# Time taken for 1 epoch 0.11273550987243652 sec
#
# Epoch 152 Batch 0 Loss 0.0894593745470047
# Epoch 152 Loss 0.17009250819683075
# Time taken for 1 epoch 0.11144781112670898 sec
#
# Epoch 153 Batch 0 Loss 0.09041404724121094
# Epoch 153 Loss 0.18230199813842773
# Time taken for 1 epoch 0.10900712013244629 sec
#
# Epoch 154 Batch 0 Loss 0.09516371041536331
# Epoch 154 Loss 0.1567200869321823
# Time taken for 1 epoch 0.11095571517944336 sec
#
# Epoch 155 Batch 0 Loss 0.08509032428264618
# Epoch 155 Loss 0.17471939325332642
# Time taken for 1 epoch 0.13757538795471191 sec
#
# Epoch 156 Batch 0 Loss 0.08469709753990173
# Epoch 156 Loss 0.16620929539203644
# Time taken for 1 epoch 0.11394333839416504 sec
#
# Epoch 157 Batch 0 Loss 0.08613280951976776
# Epoch 157 Loss 0.15323975682258606
# Time taken for 1 epoch 0.1071162223815918 sec
#
# Epoch 158 Batch 0 Loss 0.08514464646577835
# Epoch 158 Loss 0.15449778735637665
# Time taken for 1 epoch 0.11066913604736328 sec
#
# Epoch 159 Batch 0 Loss 0.08009248971939087
# Epoch 159 Loss 0.16054755449295044
# Time taken for 1 epoch 0.10706400871276855 sec
#
# Epoch 160 Batch 0 Loss 0.08124051988124847
# Epoch 160 Loss 0.15903249382972717
# Time taken for 1 epoch 0.13586068153381348 sec
#
# Epoch 161 Batch 0 Loss 0.08005962520837784
# Epoch 161 Loss 0.145944282412529
# Time taken for 1 epoch 0.11483073234558105 sec
#
# Epoch 162 Batch 0 Loss 0.08163892477750778
# Epoch 162 Loss 0.14856845140457153
# Time taken for 1 epoch 0.1084291934967041 sec
#
# Epoch 163 Batch 0 Loss 0.07782500982284546
# Epoch 163 Loss 0.15104056894779205
# Time taken for 1 epoch 0.1077425479888916 sec
#
# Epoch 164 Batch 0 Loss 0.07541407644748688
# Epoch 164 Loss 0.1405634880065918
# Time taken for 1 epoch 0.10428643226623535 sec
#
# Epoch 165 Batch 0 Loss 0.07955613732337952
# Epoch 165 Loss 0.14029920101165771
# Time taken for 1 epoch 0.14351415634155273 sec
#
# Epoch 166 Batch 0 Loss 0.07337348163127899
# Epoch 166 Loss 0.16014012694358826
# Time taken for 1 epoch 0.1058034896850586 sec
#
# Epoch 167 Batch 0 Loss 0.07729604095220566
# Epoch 167 Loss 0.13590440154075623
# Time taken for 1 epoch 0.1215972900390625 sec
#
# Epoch 168 Batch 0 Loss 0.07035312801599503
# Epoch 168 Loss 0.14885716140270233
# Time taken for 1 epoch 0.10562658309936523 sec
#
# Epoch 169 Batch 0 Loss 0.07272608578205109
# Epoch 169 Loss 0.1397373378276825
# Time taken for 1 epoch 0.10273265838623047 sec
#
# Epoch 170 Batch 0 Loss 0.07218986749649048
# Epoch 170 Loss 0.14663340151309967
# Time taken for 1 epoch 0.14590716361999512 sec
#
# Epoch 171 Batch 0 Loss 0.07107117772102356
# Epoch 171 Loss 0.13245372474193573
# Time taken for 1 epoch 0.12396240234375 sec
#
# Epoch 172 Batch 0 Loss 0.06979963183403015
# Epoch 172 Loss 0.13636083900928497
# Time taken for 1 epoch 0.12287235260009766 sec
#
# Epoch 173 Batch 0 Loss 0.06766815483570099
# Epoch 173 Loss 0.13822941482067108
# Time taken for 1 epoch 0.11744117736816406 sec
#
# Epoch 174 Batch 0 Loss 0.0652853325009346
# Epoch 174 Loss 0.14281409978866577
# Time taken for 1 epoch 0.11472105979919434 sec
#
# Epoch 175 Batch 0 Loss 0.06970370560884476
# Epoch 175 Loss 0.1374213993549347
# Time taken for 1 epoch 0.15347743034362793 sec
#
# Epoch 176 Batch 0 Loss 0.06237037479877472
# Epoch 176 Loss 0.14418382942676544
# Time taken for 1 epoch 0.11587285995483398 sec
#
# Epoch 177 Batch 0 Loss 0.0701959878206253
# Epoch 177 Loss 0.12283974885940552
# Time taken for 1 epoch 0.11347651481628418 sec
#
# Epoch 178 Batch 0 Loss 0.06332287192344666
# Epoch 178 Loss 0.14546337723731995
# Time taken for 1 epoch 0.11872029304504395 sec
#
# Epoch 179 Batch 0 Loss 0.06611348688602448
# Epoch 179 Loss 0.1423856019973755
# Time taken for 1 epoch 0.11990690231323242 sec
#
# Epoch 180 Batch 0 Loss 0.06532523781061172
# Epoch 180 Loss 0.14009612798690796
# Time taken for 1 epoch 0.14149069786071777 sec
#
# Epoch 181 Batch 0 Loss 0.06308606266975403
# Epoch 181 Loss 0.13432994484901428
# Time taken for 1 epoch 0.11993193626403809 sec
#
# Epoch 182 Batch 0 Loss 0.061423081904649734
# Epoch 182 Loss 0.13226287066936493
# Time taken for 1 epoch 0.11169576644897461 sec
#
# Epoch 183 Batch 0 Loss 0.06344880908727646
# Epoch 183 Loss 0.1350691169500351
# Time taken for 1 epoch 0.11074304580688477 sec
#
# Epoch 184 Batch 0 Loss 0.06260506808757782
# Epoch 184 Loss 0.13376499712467194
# Time taken for 1 epoch 0.10616040229797363 sec
#
# Epoch 185 Batch 0 Loss 0.06190136447548866
# Epoch 185 Loss 0.11581862717866898
# Time taken for 1 epoch 0.15830230712890625 sec
#
# Epoch 186 Batch 0 Loss 0.06106831133365631
# Epoch 186 Loss 0.12868373095989227
# Time taken for 1 epoch 0.1550436019897461 sec
#
# Epoch 187 Batch 0 Loss 0.06341107189655304
# Epoch 187 Loss 0.11838941276073456
# Time taken for 1 epoch 0.11211776733398438 sec
#
# Epoch 188 Batch 0 Loss 0.05749472603201866
# Epoch 188 Loss 0.12688617408275604
# Time taken for 1 epoch 0.12865543365478516 sec
#
# Epoch 189 Batch 0 Loss 0.062076110392808914
# Epoch 189 Loss 0.11279166489839554
# Time taken for 1 epoch 0.1212930679321289 sec
#
# Epoch 190 Batch 0 Loss 0.05964735150337219
# Epoch 190 Loss 0.11900278180837631
# Time taken for 1 epoch 0.16663599014282227 sec
#
# Epoch 191 Batch 0 Loss 0.05839306861162186
# Epoch 191 Loss 0.11711971461772919
# Time taken for 1 epoch 0.1074533462524414 sec
#
# Epoch 192 Batch 0 Loss 0.05939890816807747
# Epoch 192 Loss 0.12911687791347504
# Time taken for 1 epoch 0.10230231285095215 sec
#
# Epoch 193 Batch 0 Loss 0.05928616225719452
# Epoch 193 Loss 0.12178292870521545
# Time taken for 1 epoch 0.1114342212677002 sec
#
# Epoch 194 Batch 0 Loss 0.060718242079019547
# Epoch 194 Loss 0.11809594929218292
# Time taken for 1 epoch 0.10205578804016113 sec
#
# Epoch 195 Batch 0 Loss 0.05821015313267708
# Epoch 195 Loss 0.1172841265797615
# Time taken for 1 epoch 0.16185545921325684 sec
#
# Epoch 196 Batch 0 Loss 0.0577361024916172
# Epoch 196 Loss 0.11526813358068466
# Time taken for 1 epoch 0.1105794906616211 sec
#
# Epoch 197 Batch 0 Loss 0.05549238994717598
# Epoch 197 Loss 0.12431149184703827
# Time taken for 1 epoch 0.10787439346313477 sec
#
# Epoch 198 Batch 0 Loss 0.057594336569309235
# Epoch 198 Loss 0.1130671575665474
# Time taken for 1 epoch 0.10805773735046387 sec
#
# Epoch 199 Batch 0 Loss 0.05372951552271843
# Epoch 199 Loss 0.11323414742946625
# Time taken for 1 epoch 0.10669589042663574 sec
#
# Epoch 200 Batch 0 Loss 0.0559106320142746
# Epoch 200 Loss 0.11778493970632553
# Time taken for 1 epoch 0.13408994674682617 sec
#
# Epoch 201 Batch 0 Loss 0.056039441376924515
# Epoch 201 Loss 0.11589044332504272
# Time taken for 1 epoch 0.10344529151916504 sec
#
# Epoch 202 Batch 0 Loss 0.05603095144033432
# Epoch 202 Loss 0.10743311792612076
# Time taken for 1 epoch 0.10846233367919922 sec
#
# Epoch 203 Batch 0 Loss 0.058720093220472336
# Epoch 203 Loss 0.1182883083820343
# Time taken for 1 epoch 0.12134790420532227 sec
#
# Epoch 204 Batch 0 Loss 0.05285518243908882
# Epoch 204 Loss 0.11082948744297028
# Time taken for 1 epoch 0.12122488021850586 sec
#
# Epoch 205 Batch 0 Loss 0.05457426980137825
# Epoch 205 Loss 0.11677972972393036
# Time taken for 1 epoch 0.14749360084533691 sec
#
# Epoch 206 Batch 0 Loss 0.05585317686200142
# Epoch 206 Loss 0.10360298305749893
# Time taken for 1 epoch 0.11850261688232422 sec
#
# Epoch 207 Batch 0 Loss 0.053220998495817184
# Epoch 207 Loss 0.10549723356962204
# Time taken for 1 epoch 0.11602568626403809 sec
#
# Epoch 208 Batch 0 Loss 0.049959030002355576
# Epoch 208 Loss 0.1194118857383728
# Time taken for 1 epoch 0.11861133575439453 sec
#
# Epoch 209 Batch 0 Loss 0.05097491294145584
# Epoch 209 Loss 0.10992894321680069
# Time taken for 1 epoch 0.11410951614379883 sec
#
# Epoch 210 Batch 0 Loss 0.04965027794241905
# Epoch 210 Loss 0.11448346823453903
# Time taken for 1 epoch 0.14067554473876953 sec
#
# Epoch 211 Batch 0 Loss 0.05090882256627083
# Epoch 211 Loss 0.10589811205863953
# Time taken for 1 epoch 0.11693978309631348 sec
#
# Epoch 212 Batch 0 Loss 0.052251771092414856
# Epoch 212 Loss 0.11423654854297638
# Time taken for 1 epoch 0.11584615707397461 sec
#
# Epoch 213 Batch 0 Loss 0.049651872366666794
# Epoch 213 Loss 0.09990451484918594
# Time taken for 1 epoch 0.11663103103637695 sec
#
# Epoch 214 Batch 0 Loss 0.051293667405843735
# Epoch 214 Loss 0.11399336159229279
# Time taken for 1 epoch 0.11743831634521484 sec
#
# Epoch 215 Batch 0 Loss 0.05160069838166237
# Epoch 215 Loss 0.10806464403867722
# Time taken for 1 epoch 0.14674663543701172 sec
#
# Epoch 216 Batch 0 Loss 0.05193665996193886
# Epoch 216 Loss 0.11000882834196091
# Time taken for 1 epoch 0.10906171798706055 sec
#
# Epoch 217 Batch 0 Loss 0.05118909850716591
# Epoch 217 Loss 0.10920518636703491
# Time taken for 1 epoch 0.10788989067077637 sec
#
# Epoch 218 Batch 0 Loss 0.05190994590520859
# Epoch 218 Loss 0.09747958928346634
# Time taken for 1 epoch 0.1016240119934082 sec
#
# Epoch 219 Batch 0 Loss 0.04979719966650009
# Epoch 219 Loss 0.09766954183578491
# Time taken for 1 epoch 0.10470867156982422 sec
#
# Epoch 220 Batch 0 Loss 0.048652637749910355
# Epoch 220 Loss 0.10438071191310883
# Time taken for 1 epoch 0.13769888877868652 sec
#
# Epoch 221 Batch 0 Loss 0.053824733942747116
# Epoch 221 Loss 0.10636180639266968
# Time taken for 1 epoch 0.10898113250732422 sec
#
# Epoch 222 Batch 0 Loss 0.04791910573840141
# Epoch 222 Loss 0.101017065346241
# Time taken for 1 epoch 0.10744357109069824 sec
#
# Epoch 223 Batch 0 Loss 0.04893206059932709
# Epoch 223 Loss 0.10091692954301834
# Time taken for 1 epoch 0.10399556159973145 sec
#
# Epoch 224 Batch 0 Loss 0.04959742724895477
# Epoch 224 Loss 0.09681214392185211
# Time taken for 1 epoch 0.10287690162658691 sec
#
# Epoch 225 Batch 0 Loss 0.04581839591264725
# Epoch 225 Loss 0.10838454961776733
# Time taken for 1 epoch 0.13704252243041992 sec
#
# Epoch 226 Batch 0 Loss 0.04883328452706337
# Epoch 226 Loss 0.09846743941307068
# Time taken for 1 epoch 0.10363054275512695 sec
#
# Epoch 227 Batch 0 Loss 0.04591292887926102
# Epoch 227 Loss 0.10159118473529816
# Time taken for 1 epoch 0.11368346214294434 sec
#
# Epoch 228 Batch 0 Loss 0.04910558834671974
# Epoch 228 Loss 0.0952863097190857
# Time taken for 1 epoch 0.1104886531829834 sec
#
# Epoch 229 Batch 0 Loss 0.048566654324531555
# Epoch 229 Loss 0.10418935865163803
# Time taken for 1 epoch 0.11963391304016113 sec
#
# Epoch 230 Batch 0 Loss 0.0452410988509655
# Epoch 230 Loss 0.10293688625097275
# Time taken for 1 epoch 0.22074174880981445 sec
#
# Epoch 231 Batch 0 Loss 0.04730796813964844
# Epoch 231 Loss 0.09154300391674042
# Time taken for 1 epoch 0.12291455268859863 sec
#
# Epoch 232 Batch 0 Loss 0.047833897173404694
# Epoch 232 Loss 0.10331454128026962
# Time taken for 1 epoch 0.1079103946685791 sec
#
# Epoch 233 Batch 0 Loss 0.04394949600100517
# Epoch 233 Loss 0.10698910057544708
# Time taken for 1 epoch 0.10565471649169922 sec
#
# Epoch 234 Batch 0 Loss 0.04885795712471008
# Epoch 234 Loss 0.10260418057441711
# Time taken for 1 epoch 0.10257077217102051 sec
#
# Epoch 235 Batch 0 Loss 0.045562468469142914
# Epoch 235 Loss 0.09197378158569336
# Time taken for 1 epoch 0.14613103866577148 sec
#
# Epoch 236 Batch 0 Loss 0.04938284307718277
# Epoch 236 Loss 0.09745467454195023
# Time taken for 1 epoch 0.10882568359375 sec
#
# Epoch 237 Batch 0 Loss 0.04691142216324806
# Epoch 237 Loss 0.09418796747922897
# Time taken for 1 epoch 0.11083436012268066 sec
#
# Epoch 238 Batch 0 Loss 0.0440712608397007
# Epoch 238 Loss 0.09332295507192612
# Time taken for 1 epoch 0.1042935848236084 sec
#
# Epoch 239 Batch 0 Loss 0.043441761285066605
# Epoch 239 Loss 0.09438163042068481
# Time taken for 1 epoch 0.10458922386169434 sec
#
# Epoch 240 Batch 0 Loss 0.04538216441869736
# Epoch 240 Loss 0.09182465821504593
# Time taken for 1 epoch 0.15403270721435547 sec
#
# Epoch 241 Batch 0 Loss 0.04759126529097557
# Epoch 241 Loss 0.09455601871013641
# Time taken for 1 epoch 0.11035728454589844 sec
#
# Epoch 242 Batch 0 Loss 0.043364133685827255
# Epoch 242 Loss 0.08918851613998413
# Time taken for 1 epoch 0.11316967010498047 sec
#
# Epoch 243 Batch 0 Loss 0.04238267242908478
# Epoch 243 Loss 0.09624376147985458
# Time taken for 1 epoch 0.12644624710083008 sec
#
# Epoch 244 Batch 0 Loss 0.04481929913163185
# Epoch 244 Loss 0.09785714745521545
# Time taken for 1 epoch 0.11986780166625977 sec
#
# Epoch 245 Batch 0 Loss 0.04420894756913185
# Epoch 245 Loss 0.1007523313164711
# Time taken for 1 epoch 0.13636445999145508 sec
#
# Epoch 246 Batch 0 Loss 0.045109737664461136
# Epoch 246 Loss 0.0944073274731636
# Time taken for 1 epoch 0.10671782493591309 sec
#
# Epoch 247 Batch 0 Loss 0.044787898659706116
# Epoch 247 Loss 0.09097208082675934
# Time taken for 1 epoch 0.11195921897888184 sec
#
# Epoch 248 Batch 0 Loss 0.04243040457367897
# Epoch 248 Loss 0.09864463657140732
# Time taken for 1 epoch 0.10192203521728516 sec
#
# Epoch 249 Batch 0 Loss 0.04465280845761299
# Epoch 249 Loss 0.08493562787771225
# Time taken for 1 epoch 0.10503339767456055 sec
#
# Epoch 250 Batch 0 Loss 0.04377688467502594
# Epoch 250 Loss 0.09748478978872299
# Time taken for 1 epoch 0.13408732414245605 sec
#
# Epoch 251 Batch 0 Loss 0.04633862525224686
# Epoch 251 Loss 0.08415535092353821
# Time taken for 1 epoch 0.10536909103393555 sec
#
# Epoch 252 Batch 0 Loss 0.04376760497689247
# Epoch 252 Loss 0.08985785394906998
# Time taken for 1 epoch 0.10190010070800781 sec
#
# Epoch 253 Batch 0 Loss 0.042403582483530045
# Epoch 253 Loss 0.09659825265407562
# Time taken for 1 epoch 0.10588335990905762 sec
#
# Epoch 254 Batch 0 Loss 0.040494561195373535
# Epoch 254 Loss 0.09375473111867905
# Time taken for 1 epoch 0.10725069046020508 sec
#
# Epoch 255 Batch 0 Loss 0.04440749064087868
# Epoch 255 Loss 0.08597076684236526
# Time taken for 1 epoch 0.13318395614624023 sec
#
# Epoch 256 Batch 0 Loss 0.0415094755589962
# Epoch 256 Loss 0.09367376565933228
# Time taken for 1 epoch 0.1079261302947998 sec
#
# Epoch 257 Batch 0 Loss 0.04401865974068642
# Epoch 257 Loss 0.08370531350374222
# Time taken for 1 epoch 0.10564422607421875 sec
#
# Epoch 258 Batch 0 Loss 0.042030949145555496
# Epoch 258 Loss 0.0960339903831482
# Time taken for 1 epoch 0.10432791709899902 sec
#
# Epoch 259 Batch 0 Loss 0.04199540242552757
# Epoch 259 Loss 0.09661299735307693
# Time taken for 1 epoch 0.10557317733764648 sec
#
# Epoch 260 Batch 0 Loss 0.04032773897051811
# Epoch 260 Loss 0.08924984931945801
# Time taken for 1 epoch 0.13357019424438477 sec
#
# Epoch 261 Batch 0 Loss 0.04429680481553078
# Epoch 261 Loss 0.090108722448349
# Time taken for 1 epoch 0.10430693626403809 sec
#
# Epoch 262 Batch 0 Loss 0.04109190031886101
# Epoch 262 Loss 0.09061075001955032
# Time taken for 1 epoch 0.10803389549255371 sec
#
# Epoch 263 Batch 0 Loss 0.04473019763827324
# Epoch 263 Loss 0.08360059559345245
# Time taken for 1 epoch 0.11351394653320312 sec
#
# Epoch 264 Batch 0 Loss 0.040522824972867966
# Epoch 264 Loss 0.08428506553173065
# Time taken for 1 epoch 0.10601425170898438 sec
#
# Epoch 265 Batch 0 Loss 0.04330815002322197
# Epoch 265 Loss 0.08060169219970703
# Time taken for 1 epoch 0.13437342643737793 sec
#
# Epoch 266 Batch 0 Loss 0.04093277081847191
# Epoch 266 Loss 0.08451960235834122
# Time taken for 1 epoch 0.10606741905212402 sec
#
# Epoch 267 Batch 0 Loss 0.04012477397918701
# Epoch 267 Loss 0.08392629772424698
# Time taken for 1 epoch 0.1074361801147461 sec
#
# Epoch 268 Batch 0 Loss 0.04179427772760391
# Epoch 268 Loss 0.07804267108440399
# Time taken for 1 epoch 0.10996317863464355 sec
#
# Epoch 269 Batch 0 Loss 0.039698585867881775
# Epoch 269 Loss 0.09180846065282822
# Time taken for 1 epoch 0.10087347030639648 sec
#
# Epoch 270 Batch 0 Loss 0.04179229214787483
# Epoch 270 Loss 0.08967393636703491
# Time taken for 1 epoch 0.13028454780578613 sec
#
# Epoch 271 Batch 0 Loss 0.03922194615006447
# Epoch 271 Loss 0.09067203849554062
# Time taken for 1 epoch 0.10834121704101562 sec
#
# Epoch 272 Batch 0 Loss 0.036318372935056686
# Epoch 272 Loss 0.09344826638698578
# Time taken for 1 epoch 0.1090703010559082 sec
#
# Epoch 273 Batch 0 Loss 0.04225979745388031
# Epoch 273 Loss 0.09295446425676346
# Time taken for 1 epoch 0.10441374778747559 sec
#
# Epoch 274 Batch 0 Loss 0.039346739649772644
# Epoch 274 Loss 0.09335453063249588
# Time taken for 1 epoch 0.10283732414245605 sec
#
# Epoch 275 Batch 0 Loss 0.041497815400362015
# Epoch 275 Loss 0.08638619631528854
# Time taken for 1 epoch 0.15116024017333984 sec
#
# Epoch 276 Batch 0 Loss 0.03924160823225975
# Epoch 276 Loss 0.08444765955209732
# Time taken for 1 epoch 0.15044665336608887 sec
#
# Epoch 277 Batch 0 Loss 0.039146557450294495
# Epoch 277 Loss 0.08114868402481079
# Time taken for 1 epoch 0.11629343032836914 sec
#
# Epoch 278 Batch 0 Loss 0.039404287934303284
# Epoch 278 Loss 0.08974278718233109
# Time taken for 1 epoch 0.10568523406982422 sec
#
# Epoch 279 Batch 0 Loss 0.03876455873250961
# Epoch 279 Loss 0.08414945006370544
# Time taken for 1 epoch 0.1047515869140625 sec
#
# Epoch 280 Batch 0 Loss 0.03681841492652893
# Epoch 280 Loss 0.0863410159945488
# Time taken for 1 epoch 0.18753528594970703 sec
#
# Epoch 281 Batch 0 Loss 0.03782486915588379
# Epoch 281 Loss 0.08147204667329788
# Time taken for 1 epoch 0.10488152503967285 sec
#
# Epoch 282 Batch 0 Loss 0.03945744410157204
# Epoch 282 Loss 0.0684598758816719
# Time taken for 1 epoch 0.10710835456848145 sec
#
# Epoch 283 Batch 0 Loss 0.03995759040117264
# Epoch 283 Loss 0.08311871439218521
# Time taken for 1 epoch 0.10331225395202637 sec
#
# Epoch 284 Batch 0 Loss 0.04067254066467285
# Epoch 284 Loss 0.07616031914949417
# Time taken for 1 epoch 0.10819292068481445 sec
#
# Epoch 285 Batch 0 Loss 0.035494185984134674
# Epoch 285 Loss 0.08238699287176132
# Time taken for 1 epoch 0.16085553169250488 sec
#
# Epoch 286 Batch 0 Loss 0.03873829543590546
# Epoch 286 Loss 0.08454027026891708
# Time taken for 1 epoch 0.11275982856750488 sec
#
# Epoch 287 Batch 0 Loss 0.037459973245859146
# Epoch 287 Loss 0.08083727210760117
# Time taken for 1 epoch 0.10822129249572754 sec
#
# Epoch 288 Batch 0 Loss 0.03843522071838379
# Epoch 288 Loss 0.08412423729896545
# Time taken for 1 epoch 0.12080597877502441 sec
#
# Epoch 289 Batch 0 Loss 0.03632717579603195
# Epoch 289 Loss 0.08013177663087845
# Time taken for 1 epoch 0.1133723258972168 sec
#
# Epoch 290 Batch 0 Loss 0.03922732174396515
# Epoch 290 Loss 0.07918963581323624
# Time taken for 1 epoch 0.13701200485229492 sec
#
# Epoch 291 Batch 0 Loss 0.03835289925336838
# Epoch 291 Loss 0.07799883186817169
# Time taken for 1 epoch 0.1081695556640625 sec
#
# Epoch 292 Batch 0 Loss 0.037820965051651
# Epoch 292 Loss 0.07943065464496613
# Time taken for 1 epoch 0.10744547843933105 sec
#
# Epoch 293 Batch 0 Loss 0.036626946181058884
# Epoch 293 Loss 0.08079559355974197
# Time taken for 1 epoch 0.1223902702331543 sec
#
# Epoch 294 Batch 0 Loss 0.038959551602602005
# Epoch 294 Loss 0.06726931780576706
# Time taken for 1 epoch 0.11608099937438965 sec
#
# Epoch 295 Batch 0 Loss 0.04004473239183426
# Epoch 295 Loss 0.0744844451546669
# Time taken for 1 epoch 0.14139676094055176 sec
#
# Epoch 296 Batch 0 Loss 0.036885157227516174
# Epoch 296 Loss 0.07522983103990555
# Time taken for 1 epoch 0.11606502532958984 sec
#
# Epoch 297 Batch 0 Loss 0.040506646037101746
# Epoch 297 Loss 0.07779614627361298
# Time taken for 1 epoch 0.10544681549072266 sec
#
# Epoch 298 Batch 0 Loss 0.033846233040094376
# Epoch 298 Loss 0.07763522863388062
# Time taken for 1 epoch 0.12858366966247559 sec
#
# Epoch 299 Batch 0 Loss 0.03796745836734772
# Epoch 299 Loss 0.07506921887397766
# Time taken for 1 epoch 0.11242222785949707 sec
#
# Epoch 300 Batch 0 Loss 0.037148281931877136
# Epoch 300 Loss 0.07417052984237671
# Time taken for 1 epoch 0.1494731903076172 sec
#
# Epoch 301 Batch 0 Loss 0.03570832312107086
# Epoch 301 Loss 0.07347115874290466
# Time taken for 1 epoch 0.10359811782836914 sec
#
# Epoch 302 Batch 0 Loss 0.03655655309557915
# Epoch 302 Loss 0.08101174235343933
# Time taken for 1 epoch 0.11221051216125488 sec
#
# Epoch 303 Batch 0 Loss 0.03525291010737419
# Epoch 303 Loss 0.07343227416276932
# Time taken for 1 epoch 0.10431337356567383 sec
#
# Epoch 304 Batch 0 Loss 0.03939276561141014
# Epoch 304 Loss 0.07626202702522278
# Time taken for 1 epoch 0.1057281494140625 sec
#
# Epoch 305 Batch 0 Loss 0.03701915219426155
# Epoch 305 Loss 0.0705309584736824
# Time taken for 1 epoch 0.13883590698242188 sec
#
# Epoch 306 Batch 0 Loss 0.03787276893854141
# Epoch 306 Loss 0.0760577991604805
# Time taken for 1 epoch 0.11563682556152344 sec
#
# Epoch 307 Batch 0 Loss 0.03799991309642792
# Epoch 307 Loss 0.08049958944320679
# Time taken for 1 epoch 0.1198892593383789 sec
#
# Epoch 308 Batch 0 Loss 0.036275237798690796
# Epoch 308 Loss 0.07524377107620239
# Time taken for 1 epoch 0.11896872520446777 sec
#
# Epoch 309 Batch 0 Loss 0.03652206063270569
# Epoch 309 Loss 0.06669812649488449
# Time taken for 1 epoch 0.12109184265136719 sec
#
# Epoch 310 Batch 0 Loss 0.035482894629240036
# Epoch 310 Loss 0.07251209020614624
# Time taken for 1 epoch 0.14932036399841309 sec
#
# Epoch 311 Batch 0 Loss 0.0372452475130558
# Epoch 311 Loss 0.07036358118057251
# Time taken for 1 epoch 0.11631917953491211 sec
#
# Epoch 312 Batch 0 Loss 0.03805633634328842
# Epoch 312 Loss 0.0803150162100792
# Time taken for 1 epoch 0.1139979362487793 sec
#
# Epoch 313 Batch 0 Loss 0.03803270682692528
# Epoch 313 Loss 0.07174388319253922
# Time taken for 1 epoch 0.12012743949890137 sec
#
# Epoch 314 Batch 0 Loss 0.03617645427584648
# Epoch 314 Loss 0.07337494939565659
# Time taken for 1 epoch 0.12133455276489258 sec
#
# Epoch 315 Batch 0 Loss 0.03693258389830589
# Epoch 315 Loss 0.07611367851495743
# Time taken for 1 epoch 0.13945484161376953 sec
#
# Epoch 316 Batch 0 Loss 0.03614696115255356
# Epoch 316 Loss 0.07963269203901291
# Time taken for 1 epoch 0.1241908073425293 sec
#
# Epoch 317 Batch 0 Loss 0.03503872826695442
# Epoch 317 Loss 0.0726085975766182
# Time taken for 1 epoch 0.10874772071838379 sec
#
# Epoch 318 Batch 0 Loss 0.036292046308517456
# Epoch 318 Loss 0.07238589972257614
# Time taken for 1 epoch 0.11781740188598633 sec
#
# Epoch 319 Batch 0 Loss 0.036960043013095856
# Epoch 319 Loss 0.07371409237384796
# Time taken for 1 epoch 0.11498045921325684 sec
#
# Epoch 320 Batch 0 Loss 0.03585171699523926
# Epoch 320 Loss 0.07439037412405014
# Time taken for 1 epoch 0.16945409774780273 sec
#
# Epoch 321 Batch 0 Loss 0.03583415597677231
# Epoch 321 Loss 0.07782053202390671
# Time taken for 1 epoch 0.14510107040405273 sec
#
# Epoch 322 Batch 0 Loss 0.03504309058189392
# Epoch 322 Loss 0.0707574188709259
# Time taken for 1 epoch 0.11515665054321289 sec
#
# Epoch 323 Batch 0 Loss 0.03599127382040024
# Epoch 323 Loss 0.07104811817407608
# Time taken for 1 epoch 0.11974143981933594 sec
#
# Epoch 324 Batch 0 Loss 0.036430686712265015
# Epoch 324 Loss 0.0639319196343422
# Time taken for 1 epoch 0.11605358123779297 sec
#
# Epoch 325 Batch 0 Loss 0.03546789288520813
# Epoch 325 Loss 0.06793272495269775
# Time taken for 1 epoch 0.1566600799560547 sec
#
# Epoch 326 Batch 0 Loss 0.035270847380161285
# Epoch 326 Loss 0.07337682694196701
# Time taken for 1 epoch 0.10601401329040527 sec
#
# Epoch 327 Batch 0 Loss 0.03593586012721062
# Epoch 327 Loss 0.07444847375154495
# Time taken for 1 epoch 0.11056208610534668 sec
#
# Epoch 328 Batch 0 Loss 0.03557218238711357
# Epoch 328 Loss 0.06755902618169785
# Time taken for 1 epoch 0.11596107482910156 sec
#
# Epoch 329 Batch 0 Loss 0.03292250260710716
# Epoch 329 Loss 0.0735916793346405
# Time taken for 1 epoch 0.11479878425598145 sec
#
# Epoch 330 Batch 0 Loss 0.03403439000248909
# Epoch 330 Loss 0.06698969006538391
# Time taken for 1 epoch 0.1669604778289795 sec
#
# Epoch 331 Batch 0 Loss 0.0349343866109848
# Epoch 331 Loss 0.06832268834114075
# Time taken for 1 epoch 0.12948298454284668 sec
#
# Epoch 332 Batch 0 Loss 0.03486742079257965
# Epoch 332 Loss 0.06796683371067047
# Time taken for 1 epoch 0.11891055107116699 sec
#
# Epoch 333 Batch 0 Loss 0.03189179301261902
# Epoch 333 Loss 0.06785979121923447
# Time taken for 1 epoch 0.12154245376586914 sec
#
# Epoch 334 Batch 0 Loss 0.034469302743673325
# Epoch 334 Loss 0.06747712194919586
# Time taken for 1 epoch 0.12299442291259766 sec
#
# Epoch 335 Batch 0 Loss 0.03554012253880501
# Epoch 335 Loss 0.07021494209766388
# Time taken for 1 epoch 0.13536906242370605 sec
#
# Epoch 336 Batch 0 Loss 0.03486091271042824
# Epoch 336 Loss 0.07186880707740784
# Time taken for 1 epoch 0.1007530689239502 sec
#
# Epoch 337 Batch 0 Loss 0.03425073251128197
# Epoch 337 Loss 0.07095132768154144
# Time taken for 1 epoch 0.1078188419342041 sec
#
# Epoch 338 Batch 0 Loss 0.03523654118180275
# Epoch 338 Loss 0.06731097400188446
# Time taken for 1 epoch 0.1049048900604248 sec
#
# Epoch 339 Batch 0 Loss 0.03476245701313019
# Epoch 339 Loss 0.06433167308568954
# Time taken for 1 epoch 0.10503363609313965 sec
#
# Epoch 340 Batch 0 Loss 0.03741871193051338
# Epoch 340 Loss 0.05466398596763611
# Time taken for 1 epoch 0.1342761516571045 sec
#
# Epoch 341 Batch 0 Loss 0.034165021032094955
# Epoch 341 Loss 0.06451941281557083
# Time taken for 1 epoch 0.1110076904296875 sec
#
# Epoch 342 Batch 0 Loss 0.03630721941590309
# Epoch 342 Loss 0.07109041512012482
# Time taken for 1 epoch 0.1033029556274414 sec
#
# Epoch 343 Batch 0 Loss 0.03206508979201317
# Epoch 343 Loss 0.07327432930469513
# Time taken for 1 epoch 0.10722517967224121 sec
#
# Epoch 344 Batch 0 Loss 0.03315556421875954
# Epoch 344 Loss 0.07257107645273209
# Time taken for 1 epoch 0.10616421699523926 sec
#
# Epoch 345 Batch 0 Loss 0.033288516104221344
# Epoch 345 Loss 0.06899328529834747
# Time taken for 1 epoch 0.13576078414916992 sec
#
# Epoch 346 Batch 0 Loss 0.03434121981263161
# Epoch 346 Loss 0.05953197553753853
# Time taken for 1 epoch 0.10716485977172852 sec
#
# Epoch 347 Batch 0 Loss 0.03491102159023285
# Epoch 347 Loss 0.07491928339004517
# Time taken for 1 epoch 0.1079866886138916 sec
#
# Epoch 348 Batch 0 Loss 0.03506915643811226
# Epoch 348 Loss 0.07627172768115997
# Time taken for 1 epoch 0.10679054260253906 sec
#
# Epoch 349 Batch 0 Loss 0.031008124351501465
# Epoch 349 Loss 0.07281643152236938
# Time taken for 1 epoch 0.10642433166503906 sec
#
# Epoch 350 Batch 0 Loss 0.03367568552494049
# Epoch 350 Loss 0.06836840510368347
# Time taken for 1 epoch 0.13695979118347168 sec
#
# Epoch 351 Batch 0 Loss 0.03359152749180794
# Epoch 351 Loss 0.06782179325819016
# Time taken for 1 epoch 0.11568999290466309 sec
#
# Epoch 352 Batch 0 Loss 0.0358247309923172
# Epoch 352 Loss 0.07274066656827927
# Time taken for 1 epoch 0.1071474552154541 sec
#
# Epoch 353 Batch 0 Loss 0.03458980470895767
# Epoch 353 Loss 0.06324344873428345
# Time taken for 1 epoch 0.10532951354980469 sec
#
# Epoch 354 Batch 0 Loss 0.03329586982727051
# Epoch 354 Loss 0.06916172802448273
# Time taken for 1 epoch 0.10280323028564453 sec
#
# Epoch 355 Batch 0 Loss 0.03244901821017265
# Epoch 355 Loss 0.06758665293455124
# Time taken for 1 epoch 0.13357186317443848 sec
#
# Epoch 356 Batch 0 Loss 0.035579755902290344
# Epoch 356 Loss 0.07067523151636124
# Time taken for 1 epoch 0.1034238338470459 sec
#
# Epoch 357 Batch 0 Loss 0.03282836079597473
# Epoch 357 Loss 0.0638328567147255
# Time taken for 1 epoch 0.10831403732299805 sec
#
# Epoch 358 Batch 0 Loss 0.03578473627567291
# Epoch 358 Loss 0.06685443967580795
# Time taken for 1 epoch 0.10252523422241211 sec
#
# Epoch 359 Batch 0 Loss 0.03302145004272461
# Epoch 359 Loss 0.06715291738510132
# Time taken for 1 epoch 0.10742402076721191 sec
#
# Epoch 360 Batch 0 Loss 0.03200564906001091
# Epoch 360 Loss 0.06848389655351639
# Time taken for 1 epoch 0.13141727447509766 sec
#
# Epoch 361 Batch 0 Loss 0.03389103338122368
# Epoch 361 Loss 0.0659361407160759
# Time taken for 1 epoch 0.10779857635498047 sec
#
# Epoch 362 Batch 0 Loss 0.03230883553624153
# Epoch 362 Loss 0.06255535781383514
# Time taken for 1 epoch 0.10409927368164062 sec
#
# Epoch 363 Batch 0 Loss 0.03167778626084328
# Epoch 363 Loss 0.06916171312332153
# Time taken for 1 epoch 0.10816383361816406 sec
#
# Epoch 364 Batch 0 Loss 0.03238734230399132
# Epoch 364 Loss 0.07133202254772186
# Time taken for 1 epoch 0.12099075317382812 sec
#
# Epoch 365 Batch 0 Loss 0.03313343599438667
# Epoch 365 Loss 0.05952567979693413
# Time taken for 1 epoch 0.15407633781433105 sec
#
# Epoch 366 Batch 0 Loss 0.03435543552041054
# Epoch 366 Loss 0.06723334640264511
# Time taken for 1 epoch 0.18629884719848633 sec
#
# Epoch 367 Batch 0 Loss 0.03373913839459419
# Epoch 367 Loss 0.0656723901629448
# Time taken for 1 epoch 0.12157511711120605 sec
#
# Epoch 368 Batch 0 Loss 0.034025173634290695
# Epoch 368 Loss 0.07364488393068314
# Time taken for 1 epoch 0.12068462371826172 sec
#
# Epoch 369 Batch 0 Loss 0.03179853409528732
# Epoch 369 Loss 0.06324686855077744
# Time taken for 1 epoch 0.11242461204528809 sec
#
# Epoch 370 Batch 0 Loss 0.03348739817738533
# Epoch 370 Loss 0.0648423358798027
# Time taken for 1 epoch 0.15929460525512695 sec
#
# Epoch 371 Batch 0 Loss 0.03142157196998596
# Epoch 371 Loss 0.06160099804401398
# Time taken for 1 epoch 0.12524056434631348 sec
#
# Epoch 372 Batch 0 Loss 0.03267814591526985
# Epoch 372 Loss 0.06562620401382446
# Time taken for 1 epoch 0.11812853813171387 sec
#
# Epoch 373 Batch 0 Loss 0.03246051445603371
# Epoch 373 Loss 0.06198011711239815
# Time taken for 1 epoch 0.1320202350616455 sec
#
# Epoch 374 Batch 0 Loss 0.03225738927721977
# Epoch 374 Loss 0.0636775940656662
# Time taken for 1 epoch 0.12649321556091309 sec
#
# Epoch 375 Batch 0 Loss 0.03144237399101257
# Epoch 375 Loss 0.058663129806518555
# Time taken for 1 epoch 0.13998961448669434 sec
#
# Epoch 376 Batch 0 Loss 0.032585445791482925
# Epoch 376 Loss 0.0661933422088623
# Time taken for 1 epoch 0.10912919044494629 sec
#
# Epoch 377 Batch 0 Loss 0.030471554026007652
# Epoch 377 Loss 0.060803674161434174
# Time taken for 1 epoch 0.11527848243713379 sec
#
# Epoch 378 Batch 0 Loss 0.031647223979234695
# Epoch 378 Loss 0.060084134340286255
# Time taken for 1 epoch 0.12555456161499023 sec
#
# Epoch 379 Batch 0 Loss 0.031123094260692596
# Epoch 379 Loss 0.06311281025409698
# Time taken for 1 epoch 0.11658048629760742 sec
#
# Epoch 380 Batch 0 Loss 0.03221116214990616
# Epoch 380 Loss 0.06700155884027481
# Time taken for 1 epoch 0.14862871170043945 sec
#
# Epoch 381 Batch 0 Loss 0.03145736828446388
# Epoch 381 Loss 0.06254332512617111
# Time taken for 1 epoch 0.12744545936584473 sec
#
# Epoch 382 Batch 0 Loss 0.03306373208761215
# Epoch 382 Loss 0.06047852337360382
# Time taken for 1 epoch 0.12614059448242188 sec
#
# Epoch 383 Batch 0 Loss 0.0331108495593071
# Epoch 383 Loss 0.061664141714572906
# Time taken for 1 epoch 0.1085517406463623 sec
#
# Epoch 384 Batch 0 Loss 0.0324476957321167
# Epoch 384 Loss 0.0573279969394207
# Time taken for 1 epoch 0.12867045402526855 sec
#
# Epoch 385 Batch 0 Loss 0.03142423927783966
# Epoch 385 Loss 0.05950280651450157
# Time taken for 1 epoch 0.16563057899475098 sec
#
# Epoch 386 Batch 0 Loss 0.03382335230708122
# Epoch 386 Loss 0.05612310394644737
# Time taken for 1 epoch 0.12555980682373047 sec
#
# Epoch 387 Batch 0 Loss 0.03338760510087013
# Epoch 387 Loss 0.06090964749455452
# Time taken for 1 epoch 0.12461614608764648 sec
#
# Epoch 388 Batch 0 Loss 0.03405028209090233
# Epoch 388 Loss 0.0663968101143837
# Time taken for 1 epoch 0.1231997013092041 sec
#
# Epoch 389 Batch 0 Loss 0.03197840228676796
# Epoch 389 Loss 0.06673213839530945
# Time taken for 1 epoch 0.12908506393432617 sec
#
# Epoch 390 Batch 0 Loss 0.031690310686826706
# Epoch 390 Loss 0.06445211172103882
# Time taken for 1 epoch 0.14780306816101074 sec
#
# Epoch 391 Batch 0 Loss 0.03419024869799614
# Epoch 391 Loss 0.0701034814119339
# Time taken for 1 epoch 0.1060333251953125 sec
#
# Epoch 392 Batch 0 Loss 0.03437833487987518
# Epoch 392 Loss 0.05925291031599045
# Time taken for 1 epoch 0.1110374927520752 sec
#
# Epoch 393 Batch 0 Loss 0.031268056482076645
# Epoch 393 Loss 0.06018836051225662
# Time taken for 1 epoch 0.12268686294555664 sec
#
# Epoch 394 Batch 0 Loss 0.03170178830623627
# Epoch 394 Loss 0.0612495131790638
# Time taken for 1 epoch 0.1231844425201416 sec
#
# Epoch 395 Batch 0 Loss 0.032671671360731125
# Epoch 395 Loss 0.06410916894674301
# Time taken for 1 epoch 0.15610337257385254 sec
#
# Epoch 396 Batch 0 Loss 0.030323738232254982
# Epoch 396 Loss 0.056825462728738785
# Time taken for 1 epoch 0.1289520263671875 sec
#
# Epoch 397 Batch 0 Loss 0.03003695420920849
# Epoch 397 Loss 0.06654826551675797
# Time taken for 1 epoch 0.11317610740661621 sec
#
# Epoch 398 Batch 0 Loss 0.03283906355500221
# Epoch 398 Loss 0.05853332579135895
# Time taken for 1 epoch 0.11707115173339844 sec
#
# Epoch 399 Batch 0 Loss 0.03424304723739624
# Epoch 399 Loss 0.05656557157635689
# Time taken for 1 epoch 0.11007189750671387 sec
#
# Epoch 400 Batch 0 Loss 0.03351306915283203
# Epoch 400 Loss 0.05818546190857887
# Time taken for 1 epoch 0.1683347225189209 sec
#
# Epoch 401 Batch 0 Loss 0.033438004553318024
# Epoch 401 Loss 0.06333091109991074
# Time taken for 1 epoch 0.13224053382873535 sec
#
# Epoch 402 Batch 0 Loss 0.03319767862558365
# Epoch 402 Loss 0.05976792424917221
# Time taken for 1 epoch 0.10671734809875488 sec
#
# Epoch 403 Batch 0 Loss 0.03165692463517189
# Epoch 403 Loss 0.05727992206811905
# Time taken for 1 epoch 0.10898780822753906 sec
#
# Epoch 404 Batch 0 Loss 0.03135775402188301
# Epoch 404 Loss 0.06571132689714432
# Time taken for 1 epoch 0.11384820938110352 sec
#
# Epoch 405 Batch 0 Loss 0.033975180238485336
# Epoch 405 Loss 0.06448230892419815
# Time taken for 1 epoch 0.16259336471557617 sec
#
# Epoch 406 Batch 0 Loss 0.033122628927230835
# Epoch 406 Loss 0.06333522498607635
# Time taken for 1 epoch 0.11039018630981445 sec
#
# Epoch 407 Batch 0 Loss 0.03186335787177086
# Epoch 407 Loss 0.059415388852357864
# Time taken for 1 epoch 0.10980772972106934 sec
#
# Epoch 408 Batch 0 Loss 0.029667213559150696
# Epoch 408 Loss 0.05401468649506569
# Time taken for 1 epoch 0.10833454132080078 sec
#
# Epoch 409 Batch 0 Loss 0.030217105522751808
# Epoch 409 Loss 0.06283890455961227
# Time taken for 1 epoch 0.10962224006652832 sec
#
# Epoch 410 Batch 0 Loss 0.034621838480234146
# Epoch 410 Loss 0.0615173801779747
# Time taken for 1 epoch 0.17572283744812012 sec
#
# Epoch 411 Batch 0 Loss 0.032432422041893005
# Epoch 411 Loss 0.05831587687134743
# Time taken for 1 epoch 0.12173819541931152 sec
#
# Epoch 412 Batch 0 Loss 0.02926928550004959
# Epoch 412 Loss 0.061248015612363815
# Time taken for 1 epoch 0.12942862510681152 sec
#
# Epoch 413 Batch 0 Loss 0.030463017523288727
# Epoch 413 Loss 0.05648292228579521
# Time taken for 1 epoch 0.13137078285217285 sec
#
# Epoch 414 Batch 0 Loss 0.029000606387853622
# Epoch 414 Loss 0.05960883945226669
# Time taken for 1 epoch 0.12679100036621094 sec
#
# Epoch 415 Batch 0 Loss 0.03161614388227463
# Epoch 415 Loss 0.05461699515581131
# Time taken for 1 epoch 0.14424610137939453 sec
#
# Epoch 416 Batch 0 Loss 0.03106001578271389
# Epoch 416 Loss 0.05815775319933891
# Time taken for 1 epoch 0.11200857162475586 sec
#
# Epoch 417 Batch 0 Loss 0.029251299798488617
# Epoch 417 Loss 0.062488045543432236
# Time taken for 1 epoch 0.11541175842285156 sec
#
# Epoch 418 Batch 0 Loss 0.03218742087483406
# Epoch 418 Loss 0.04989711940288544
# Time taken for 1 epoch 0.10704421997070312 sec
#
# Epoch 419 Batch 0 Loss 0.03118169493973255
# Epoch 419 Loss 0.06423795968294144
# Time taken for 1 epoch 0.1044166088104248 sec
#
# Epoch 420 Batch 0 Loss 0.0317341573536396
# Epoch 420 Loss 0.05914871767163277
# Time taken for 1 epoch 0.13697600364685059 sec
#
# Epoch 421 Batch 0 Loss 0.028730416670441628
# Epoch 421 Loss 0.062200576066970825
# Time taken for 1 epoch 0.11160564422607422 sec
#
# Epoch 422 Batch 0 Loss 0.02971278876066208
# Epoch 422 Loss 0.06081360951066017
# Time taken for 1 epoch 0.10583090782165527 sec
#
# Epoch 423 Batch 0 Loss 0.027953503653407097
# Epoch 423 Loss 0.05961333215236664
# Time taken for 1 epoch 0.10634303092956543 sec
#
# Epoch 424 Batch 0 Loss 0.029186608269810677
# Epoch 424 Loss 0.05604444444179535
# Time taken for 1 epoch 0.11537933349609375 sec
#
# Epoch 425 Batch 0 Loss 0.03224928677082062
# Epoch 425 Loss 0.06266308575868607
# Time taken for 1 epoch 0.15842819213867188 sec
#
# Epoch 426 Batch 0 Loss 0.03081137128174305
# Epoch 426 Loss 0.0562831312417984
# Time taken for 1 epoch 0.11816143989562988 sec
#
# Epoch 427 Batch 0 Loss 0.03075992502272129
# Epoch 427 Loss 0.05472864955663681
# Time taken for 1 epoch 0.11505937576293945 sec
#
# Epoch 428 Batch 0 Loss 0.03135719895362854
# Epoch 428 Loss 0.05376198887825012
# Time taken for 1 epoch 0.1202695369720459 sec
#
# Epoch 429 Batch 0 Loss 0.03248443827033043
# Epoch 429 Loss 0.06267058104276657
# Time taken for 1 epoch 0.13870787620544434 sec
#
# Epoch 430 Batch 0 Loss 0.03183799237012863
# Epoch 430 Loss 0.05545372888445854
# Time taken for 1 epoch 0.15224146842956543 sec
#
# Epoch 431 Batch 0 Loss 0.03285018354654312
# Epoch 431 Loss 0.056892428547143936
# Time taken for 1 epoch 0.11066126823425293 sec
#
# Epoch 432 Batch 0 Loss 0.03322325646877289
# Epoch 432 Loss 0.05879896506667137
# Time taken for 1 epoch 0.11338043212890625 sec
#
# Epoch 433 Batch 0 Loss 0.029374418780207634
# Epoch 433 Loss 0.05775994434952736
# Time taken for 1 epoch 0.12407064437866211 sec
#
# Epoch 434 Batch 0 Loss 0.033335547894239426
# Epoch 434 Loss 0.055057451128959656
# Time taken for 1 epoch 0.10927915573120117 sec
#
# Epoch 435 Batch 0 Loss 0.0318647176027298
# Epoch 435 Loss 0.0632457360625267
# Time taken for 1 epoch 0.13603663444519043 sec
#
# Epoch 436 Batch 0 Loss 0.03172898292541504
# Epoch 436 Loss 0.052409593015909195
# Time taken for 1 epoch 0.11703109741210938 sec
#
# Epoch 437 Batch 0 Loss 0.03018777444958687
# Epoch 437 Loss 0.06327127665281296
# Time taken for 1 epoch 0.10695171356201172 sec
#
# Epoch 438 Batch 0 Loss 0.029904546216130257
# Epoch 438 Loss 0.05990191549062729
# Time taken for 1 epoch 0.10655021667480469 sec
#
# Epoch 439 Batch 0 Loss 0.030806612223386765
# Epoch 439 Loss 0.05783724784851074
# Time taken for 1 epoch 0.11265897750854492 sec
#
# Epoch 440 Batch 0 Loss 0.029533294960856438
# Epoch 440 Loss 0.05677446722984314
# Time taken for 1 epoch 0.14043545722961426 sec
#
# Epoch 441 Batch 0 Loss 0.03054756484925747
# Epoch 441 Loss 0.0566972941160202
# Time taken for 1 epoch 0.1089472770690918 sec
#
# Epoch 442 Batch 0 Loss 0.02869722805917263
# Epoch 442 Loss 0.054215382784605026
# Time taken for 1 epoch 0.11266946792602539 sec
#
# Epoch 443 Batch 0 Loss 0.02996191941201687
# Epoch 443 Loss 0.05733073130249977
# Time taken for 1 epoch 0.10780119895935059 sec
#
# Epoch 444 Batch 0 Loss 0.02977990359067917
# Epoch 444 Loss 0.053161028772592545
# Time taken for 1 epoch 0.12720012664794922 sec
#
# Epoch 445 Batch 0 Loss 0.029920754954218864
# Epoch 445 Loss 0.05323120951652527
# Time taken for 1 epoch 0.1689138412475586 sec
#
# Epoch 446 Batch 0 Loss 0.03046453557908535
# Epoch 446 Loss 0.05639481544494629
# Time taken for 1 epoch 0.13684487342834473 sec
#
# Epoch 447 Batch 0 Loss 0.03150712326169014
# Epoch 447 Loss 0.05875342711806297
# Time taken for 1 epoch 0.10647082328796387 sec
#
# Epoch 448 Batch 0 Loss 0.031306192278862
# Epoch 448 Loss 0.05149352550506592
# Time taken for 1 epoch 0.11877250671386719 sec
#
# Epoch 449 Batch 0 Loss 0.03036678023636341
# Epoch 449 Loss 0.05733118951320648
# Time taken for 1 epoch 0.11361312866210938 sec
#
# Epoch 450 Batch 0 Loss 0.029974794015288353
# Epoch 450 Loss 0.052057910710573196
# Time taken for 1 epoch 0.17845654487609863 sec
#
# Epoch 451 Batch 0 Loss 0.028873631730675697
# Epoch 451 Loss 0.06174750253558159
# Time taken for 1 epoch 0.11736726760864258 sec
#
# Epoch 452 Batch 0 Loss 0.03046041913330555
# Epoch 452 Loss 0.05109113082289696
# Time taken for 1 epoch 0.11706161499023438 sec
#
# Epoch 453 Batch 0 Loss 0.029087435454130173
# Epoch 453 Loss 0.05885529890656471
# Time taken for 1 epoch 0.11649179458618164 sec
#
# Epoch 454 Batch 0 Loss 0.029223527759313583
# Epoch 454 Loss 0.05119316279888153
# Time taken for 1 epoch 0.11443829536437988 sec
#
# Epoch 455 Batch 0 Loss 0.03292073309421539
# Epoch 455 Loss 0.05466584116220474
# Time taken for 1 epoch 0.17113780975341797 sec
#
# Epoch 456 Batch 0 Loss 0.03085695579648018
# Epoch 456 Loss 0.05502498149871826
# Time taken for 1 epoch 0.11137676239013672 sec
#
# Epoch 457 Batch 0 Loss 0.029727332293987274
# Epoch 457 Loss 0.05474327132105827
# Time taken for 1 epoch 0.11309957504272461 sec
#
# Epoch 458 Batch 0 Loss 0.029710402712225914
# Epoch 458 Loss 0.06045883148908615
# Time taken for 1 epoch 0.11613154411315918 sec
#
# Epoch 459 Batch 0 Loss 0.029078038409352303
# Epoch 459 Loss 0.05309060588479042
# Time taken for 1 epoch 0.10294604301452637 sec
#
# Epoch 460 Batch 0 Loss 0.027648568153381348
# Epoch 460 Loss 0.05890829861164093
# Time taken for 1 epoch 0.1334221363067627 sec
#
# Epoch 461 Batch 0 Loss 0.02999551221728325
# Epoch 461 Loss 0.052664801478385925
# Time taken for 1 epoch 0.1043844223022461 sec
#
# Epoch 462 Batch 0 Loss 0.030963916331529617
# Epoch 462 Loss 0.05765526741743088
# Time taken for 1 epoch 0.10530900955200195 sec
#
# Epoch 463 Batch 0 Loss 0.03086858242750168
# Epoch 463 Loss 0.05456376448273659
# Time taken for 1 epoch 0.10924887657165527 sec
#
# Epoch 464 Batch 0 Loss 0.03046582266688347
# Epoch 464 Loss 0.05590176582336426
# Time taken for 1 epoch 0.10666990280151367 sec
#
# Epoch 465 Batch 0 Loss 0.030225977301597595
# Epoch 465 Loss 0.04970531910657883
# Time taken for 1 epoch 0.15167737007141113 sec
#
# Epoch 466 Batch 0 Loss 0.031015368178486824
# Epoch 466 Loss 0.05073331296443939
# Time taken for 1 epoch 0.11365962028503418 sec
#
# Epoch 467 Batch 0 Loss 0.027892425656318665
# Epoch 467 Loss 0.055668238550424576
# Time taken for 1 epoch 0.11783862113952637 sec
#
# Epoch 468 Batch 0 Loss 0.02840111218392849
# Epoch 468 Loss 0.05372272804379463
# Time taken for 1 epoch 0.1166982650756836 sec
#
# Epoch 469 Batch 0 Loss 0.027306677773594856
# Epoch 469 Loss 0.05225886404514313
# Time taken for 1 epoch 0.11722779273986816 sec
#
# Epoch 470 Batch 0 Loss 0.03094659000635147
# Epoch 470 Loss 0.0507332906126976
# Time taken for 1 epoch 0.15238070487976074 sec
#
# Epoch 471 Batch 0 Loss 0.03018915466964245
# Epoch 471 Loss 0.05372238531708717
# Time taken for 1 epoch 0.11264204978942871 sec
#
# Epoch 472 Batch 0 Loss 0.02882516384124756
# Epoch 472 Loss 0.053554605692625046
# Time taken for 1 epoch 0.10634231567382812 sec
#
# Epoch 473 Batch 0 Loss 0.02970270626246929
# Epoch 473 Loss 0.054334383457899094
# Time taken for 1 epoch 0.10433006286621094 sec
#
# Epoch 474 Batch 0 Loss 0.030512232333421707
# Epoch 474 Loss 0.058003321290016174
# Time taken for 1 epoch 0.10899758338928223 sec
#
# Epoch 475 Batch 0 Loss 0.028239410370588303
# Epoch 475 Loss 0.05483461543917656
# Time taken for 1 epoch 0.1416027545928955 sec
#
# Epoch 476 Batch 0 Loss 0.030369097366929054
# Epoch 476 Loss 0.05308128520846367
# Time taken for 1 epoch 0.1291358470916748 sec
#
# Epoch 477 Batch 0 Loss 0.029234709218144417
# Epoch 477 Loss 0.05298147723078728
# Time taken for 1 epoch 0.11374688148498535 sec
#
# Epoch 478 Batch 0 Loss 0.030932798981666565
# Epoch 478 Loss 0.049086909741163254
# Time taken for 1 epoch 0.1183478832244873 sec
#
# Epoch 479 Batch 0 Loss 0.030497297644615173
# Epoch 479 Loss 0.05304728448390961
# Time taken for 1 epoch 0.11231064796447754 sec
#
# Epoch 480 Batch 0 Loss 0.02982080914080143
# Epoch 480 Loss 0.0502428263425827
# Time taken for 1 epoch 0.1542665958404541 sec
#
# Epoch 481 Batch 0 Loss 0.028858527541160583
# Epoch 481 Loss 0.05055422708392143
# Time taken for 1 epoch 0.1018679141998291 sec
#
# Epoch 482 Batch 0 Loss 0.02966839075088501
# Epoch 482 Loss 0.052245378494262695
# Time taken for 1 epoch 0.11242389678955078 sec
#
# Epoch 483 Batch 0 Loss 0.031009502708911896
# Epoch 483 Loss 0.056857120245695114
# Time taken for 1 epoch 0.10243988037109375 sec
#
# Epoch 484 Batch 0 Loss 0.02944200113415718
# Epoch 484 Loss 0.05244977027177811
# Time taken for 1 epoch 0.11644196510314941 sec
#
# Epoch 485 Batch 0 Loss 0.03146043419837952
# Epoch 485 Loss 0.05460067838430405
# Time taken for 1 epoch 0.14703893661499023 sec
#
# Epoch 486 Batch 0 Loss 0.030483664944767952
# Epoch 486 Loss 0.05087820068001747
# Time taken for 1 epoch 0.11801862716674805 sec
#
# Epoch 487 Batch 0 Loss 0.02805192396044731
# Epoch 487 Loss 0.05072450637817383
# Time taken for 1 epoch 0.11013317108154297 sec
#
# Epoch 488 Batch 0 Loss 0.029604589566588402
# Epoch 488 Loss 0.05265289172530174
# Time taken for 1 epoch 0.12594342231750488 sec
#
# Epoch 489 Batch 0 Loss 0.029180916026234627
# Epoch 489 Loss 0.05194162204861641
# Time taken for 1 epoch 0.1078951358795166 sec
#
# Epoch 490 Batch 0 Loss 0.029592785984277725
# Epoch 490 Loss 0.05172568932175636
# Time taken for 1 epoch 0.14750313758850098 sec
#
# Epoch 491 Batch 0 Loss 0.02812107652425766
# Epoch 491 Loss 0.05268354341387749
# Time taken for 1 epoch 0.14616703987121582 sec
#
# Epoch 492 Batch 0 Loss 0.02999822422862053
# Epoch 492 Loss 0.04721793159842491
# Time taken for 1 epoch 0.10230731964111328 sec
#
# Epoch 493 Batch 0 Loss 0.029006754979491234
# Epoch 493 Loss 0.04970623552799225
# Time taken for 1 epoch 0.1042332649230957 sec
#
# Epoch 494 Batch 0 Loss 0.029147423803806305
# Epoch 494 Loss 0.05285688489675522
# Time taken for 1 epoch 0.1153256893157959 sec
#
# Epoch 495 Batch 0 Loss 0.028038401156663895
# Epoch 495 Loss 0.04866666719317436
# Time taken for 1 epoch 0.16675257682800293 sec
#
# Epoch 496 Batch 0 Loss 0.027125168591737747
# Epoch 496 Loss 0.04372786357998848
# Time taken for 1 epoch 0.12184000015258789 sec
#
# Epoch 497 Batch 0 Loss 0.028397951275110245
# Epoch 497 Loss 0.050320979207754135
# Time taken for 1 epoch 0.10764193534851074 sec
#
# Epoch 498 Batch 0 Loss 0.029090052470564842
# Epoch 498 Loss 0.05218828096985817
# Time taken for 1 epoch 0.10675382614135742 sec
#
# Epoch 499 Batch 0 Loss 0.03008316084742546
# Epoch 499 Loss 0.0471731573343277
# Time taken for 1 epoch 0.10475564002990723 sec
#
# Epoch 500 Batch 0 Loss 0.028626566752791405
# Epoch 500 Loss 0.05003940686583519
# Time taken for 1 epoch 0.14662528038024902 sec
